# %% [markdown]
# # Search and Scraping

# %% [markdown]
# The imports below are:
# - bs4 (a.k.a. BeautifulSoup) for getting the html from the websites
# - requests for the searching part on the internet

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Search

# %% [markdown]
# As you can see below it requests an input for the search query.
# For now this is just the input method so you can manually search for something and see if it works

# %%
url = "https://www.bing.com/search?q="+input()
print(url)
page = requests.get(url)

soup = BeautifulSoup(page.text,"html")
# Out:
# https://www.bing.com/search?q=something

# %% [markdown]
# Bing works with links that are coupled to the H2 html tag.
# So if we get everything related to the H2 and then search for the a html tag within we can see if its a link or not.

# %%
BingLinks= soup.find_all("h2")
links =[]

for link in BingLinks:
    a =link.find("a",href=True)
    href = a['href']
    links.append(href)

# %% [markdown]
# Here below we can which links it found with the Bing search engine.

# %%
links
# Out:
# ['https://www.youtube.com/watch?v=UelDrZ1aFeY',
#  'https://nl.wikipedia.org/wiki/Something_(The_Beatles)',
#  'https://en.wikipedia.org/wiki/Something_(Beatles_song)',
#  'https://dictionary.cambridge.org/dictionary/english/something',
#  'https://www.youtube.com/watch?v=VWO3nEuWo4k',
#  'https://nl.bab.la/woordenboek/engels-nederlands/something',
#  'https://www.youtube.com/watch?v=cNavPZ8GA6I',
#  'https://en.wiktionary.org/wiki/something',
#  'https://www.thebeatles.com/something',
#  'https://genius.com/The-beatles-something-lyrics',
#  'https://www.wordreference.com/definition/something',
#  'https://www.oxfordlearnersdictionaries.com/definition/english/something_1',
#  'https://www.mijnwoordenboek.nl/vertaal/EN/NL/something',
#  'https://dictionary.cambridge.org/us/dictionary/english/something',
#  'https://www.dictionary.com/browse/something',
#  'https://www.youtube.com/watch?v=uXRvmkQLyTc',
#  'https://www.merriam-webster.com/dictionary/something',
#  'https://context.reverso.net/vertaling/engels-nederlands/something',
#  'https://www.collinsdictionary.com/dictionary/english/something',
#  'https://www.britannica.com/dictionary/something',
#  'https://www.youtube.com/watch?v=MZ3Vh8jZFdE',
#  'https://prosettings.net/players/something/',
#  'https://www.merriam-webster.com/thesaurus/something']

# %% [markdown]
# Now I'm going to make a matrix of links and the found paragraphs within these websites.
# I have chosen to search on the `p` html tag because most websites will have their text inside this tag.

# %%
paragraphs =[['0' for x in range(2)] for y in range(len(links)) ]

# %% [markdown]
# ## Scraper

# %% [markdown]
# Now we are going to scrape through every website we can find.
# Hereby we need to add some extra imports these being:
# - ConnectTimeout as sometimes you can't load the website.
# - TooManyRedirects if the page redirects to another page but the bot doesn't follow easily.
#
# I also have a general exception catcher if something does go wrong it will catch it.

# %%
from http.client import RemoteDisconnected
from requests import ConnectTimeout, TooManyRedirects


i=0
for link in links:
    print(link)
    try:
        page = requests.get(link,allow_redirects=True,timeout=100)
        soup = BeautifulSoup(page.text,"html")
        ps =soup.find_all("p")
        paragraphs[i][1] =ps
    except TooManyRedirects:
        print("Failed for ",link)
    except ConnectTimeout:
        print("Failed for ",link)
    except Exception as e:
        print("Unknown error, for ",link)
    finally:
        paragraphs[i][0] =link
        i=i+1
# Out:
# https://www.youtube.com/watch?v=UelDrZ1aFeY
# https://nl.wikipedia.org/wiki/Something_(The_Beatles)
# https://en.wikipedia.org/wiki/Something_(Beatles_song)
# https://dictionary.cambridge.org/dictionary/english/something
# Unknown error, for  https://dictionary.cambridge.org/dictionary/english/something
# https://www.youtube.com/watch?v=VWO3nEuWo4k
# https://nl.bab.la/woordenboek/engels-nederlands/something
# https://www.youtube.com/watch?v=cNavPZ8GA6I
# https://en.wiktionary.org/wiki/something
# https://www.thebeatles.com/something
# https://genius.com/The-beatles-something-lyrics
# https://www.wordreference.com/definition/something
# https://www.oxfordlearnersdictionaries.com/definition/english/something_1
# Unknown error, for  https://www.oxfordlearnersdictionaries.com/definition/english/something_1
# https://www.mijnwoordenboek.nl/vertaal/EN/NL/something
# https://dictionary.cambridge.org/us/dictionary/english/something
# Unknown error, for  https://dictionary.cambridge.org/us/dictionary/english/something
# https://www.dictionary.com/browse/something
# https://www.youtube.com/watch?v=uXRvmkQLyTc
# https://www.merriam-webster.com/dictionary/something
# https://context.reverso.net/vertaling/engels-nederlands/something
# https://www.collinsdictionary.com/dictionary/english/something
# https://www.britannica.com/dictionary/something
# https://www.youtube.com/watch?v=MZ3Vh8jZFdE
# https://prosettings.net/players/something/
# https://www.merriam-webster.com/thesaurus/something

# %% [markdown]
# ### Making into a DataFrame
# I want to make it into a DataFrame so it will be easier to manipulate and transform it to other things such as a csv file.
# For this I will use pandas as its one of the well known tools to make DataFrames with.
#
# I also import warnings because I needed to ignore a warning of pandas because I didn't find an easier way of doing something.
# More information later down in a block where it happens

# %%
import pandas as pd
import warnings

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
df = pd.DataFrame(columns=["Link","Paragraphs"],data=paragraphs)
df
# Out:
#                                                  Link  \
# 0         https://www.youtube.com/watch?v=UelDrZ1aFeY
# 1   https://nl.wikipedia.org/wiki/Something_(The_B...
# 2   https://en.wikipedia.org/wiki/Something_(Beatl...
# 3   https://dictionary.cambridge.org/dictionary/en...
# 4         https://www.youtube.com/watch?v=VWO3nEuWo4k
# 5   https://nl.bab.la/woordenboek/engels-nederland...
# 6         https://www.youtube.com/watch?v=cNavPZ8GA6I
# 7            https://en.wiktionary.org/wiki/something
# 8                https://www.thebeatles.com/something
# 9     https://genius.com/The-beatles-something-lyrics
# 10  https://www.wordreference.com/definition/somet...
# 11  https://www.oxfordlearnersdictionaries.com/def...
# 12  https://www.mijnwoordenboek.nl/vertaal/EN/NL/s...
# 13  https://dictionary.cambridge.org/us/dictionary...
# 14        https://www.dictionary.com/browse/something
# 15        https://www.youtube.com/watch?v=uXRvmkQLyTc
# 16  https://www.merriam-webster.com/dictionary/som...
# 17  https://context.reverso.net/vertaling/engels-n...
# 18  https://www.collinsdictionary.com/dictionary/e...
# 19    https://www.britannica.com/dictionary/something
# 20        https://www.youtube.com/watch?v=MZ3Vh8jZFdE
# 21         https://prosettings.net/players/something/
# 22  https://www.merriam-webster.com/thesaurus/some...
#
#                                            Paragraphs
# 0                                                  []
# 1   [[[<b>Something</b>],  is een nummer van de , ...
# 2   [[\n\n\n], [", [Something], " is a song by the...
# 3                                                   0
# 4                                                  []
# 5   [[This website is using a security service to ...
# 6                                                  []
# 7   [[From , [<a class="extiw" href="https://en.wi...
# 8   [[Song], [[Release date:],  06 October 1969], ...
# 9   [[Produced by], [], [How to Format Lyrics:], [...
# 10  [[Forum discussions with the word(s) "somethin...
# 11                                                  0
# 12                                [[[<span></span>]]]
# 13                                                  0
# 14  [[some thing; a certain undetermined or unspec...
# 15                                                 []
# 16  [[something], [Adverb], [Pronoun], [before the...
# 17  [[\n          You've been denied access â IP...
# 18  [[This website is using a security service to ...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [[something\n                            , [<s...

# %% [markdown]
# In the block below I search for the longest length of paragraphs that is inside of the DataFrame currently.

# %%
max_para: int = 0


for i in range(df["Paragraphs"].__len__()):
    x =len(df["Paragraphs"][i])
    if(max_para < x):
        max_para =x 

print(max_para)
# Out:
# 67

# %% [markdown]
# Now in the following block I will make the columns for where the paragraphs will be separated.

# %%
df_add = pd.DataFrame({"List_Link": df["Paragraphs"]})

for x in range(max_para):
    column: str =("Paragraphs")+x.__str__()
    df_add.loc[:,column] = None

# %% [markdown]
# In this block I will do something that is not recommended such as doing a double for loop where I iterate through the DataFrame so I can add the paragraph at the correct place in the DataFrame column and row

# %%
x=0
for ps in df["Paragraphs"]:   
   n=0
   for p in ps:
      column: str =("Paragraphs")+n.__str__()
      # print(column)
      df_add[column][x] = p.__str__()
      n=n+1
   x=x+1

df_add
# Out:
#                                             List_Link  \
# 0                                                  []
# 1   [[[<b>Something</b>],  is een nummer van de , ...
# 2   [[\n\n\n], [", [Something], " is a song by the...
# 3                                                   0
# 4                                                  []
# 5   [[This website is using a security service to ...
# 6                                                  []
# 7   [[From , [<a class="extiw" href="https://en.wi...
# 8   [[Song], [[Release date:],  06 October 1969], ...
# 9   [[Produced by], [], [How to Format Lyrics:], [...
# 10  [[Forum discussions with the word(s) "somethin...
# 11                                                  0
# 12                                [[[<span></span>]]]
# 13                                                  0
# 14  [[some thing; a certain undetermined or unspec...
# 15                                                 []
# 16  [[something], [Adverb], [Pronoun], [before the...
# 17  [[\n          You've been denied access â IP...
# 18  [[This website is using a security service to ...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [[something\n                            , [<s...
#
#                                           Paragraphs0  \
# 0                                                None
# 1   <p><i><b>Something</b></i> is een nummer van d...
# 2                  <p class="mw-empty-elt">\n\n\n</p>
# 3                                                   0
# 4                                                None
# 5   <p data-translate="blocked_why_detail">This we...
# 6                                                None
# 7   <p>From <span class="etyl"><a class="extiw" hr...
# 8                       <p class="pre-title">Song</p>
# 9   <p class="HeaderCredits__Label-wx7h8g-2 ghcavQ...
# 10  <p id="threadsHeader" title='Forum discussions...
# 11                                                  0
# 12  <p id="back-top"><a href="#top"><span></span><...
# 13                                                  0
# 14  <p>some thing; a certain undetermined or unspe...
# 15                                               None
# 16                     <p class="hword">something</p>
# 17  <p class="text" id="text-en" style="display: n...
# 18  <p data-translate="blocked_why_detail">This we...
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p class="hword">something\n                  ...
#
#                                           Paragraphs1  \
# 0                                                None
# 1   <p>De openingszin "Something in the way she mo...
# 2   <p>"<b>Something</b>" is a song by the English...
# 3                                                None
# 4                                                None
# 5   <p data-translate="blocked_resolve_detail">You...
# 6                                                None
# 7   <p><span class="headword-line"><strong class="...
# 8   <p class="subtitle"><span class="font-heavy">R...
# 9   <p class="SongPage__HeaderSpace-sc-19xhmoi-1 g...
# 10  <p class="other_languages"><span title="In oth...
# 11                                               None
# 12                                               None
# 13                                               None
# 14  <p>an additional amount, as of cents or minute...
# 15                                               None
# 16               <p class="function-label">Adverb</p>
# 17  <p class="text" id="text-fr" style="display: n...
# 18  <p data-translate="blocked_resolve_detail">You...
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p class="function-label">Synonyms &amp; Simil...
#
#                                           Paragraphs2  \
# 0                                                None
# 1   <p>Het lied werd door Harrison geschreven als ...
# 2   <p>The track is generally considered a love so...
# 3                                                None
# 4                                                None
# 5   <p class="text-13">\n    <span class="cf-foote...
# 6                                                None
# 7   <p><span class="headword-line"><strong class="...
# 8                                             <p></p>
# 9                        <p>How to Format Lyrics:</p>
# 10  <p style="margin-right:-2px">\n               ...
# 11                                               None
# 12                                               None
# 13                                               None
# 14  <p><span class="luna-label italic">Informal</s...
# 15                                               None
# 16              <p class="function-label">Pronoun</p>
# 17  <p class="developers">Developed by Prompsit La...
# 18  <p class="text-13">\n    <span class="cf-foote...
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p class="function-label">Antonyms &amp; Near ...
#
#                                           Paragraphs3  \
# 0                                                None
# 1   <p>De bijbehorende promotieclip is vlak na de ...
# 2   <p>"Something" received the <a class="mw-redir...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   <p><span class="headword-line"><strong class="...
# 8   <p>Something in the way she moves<br/>\nAttrac...
# 9   <p>To learn more, check out our <a class="Styl...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14   <p>in some degree; to some extent; somewhat.</p>
# 15                                               None
# 16  <p class="ety-sl pb-3" data-entry-id="1">befor...
# 17  <p class="copy">Â© 2017 Softissimo Inc. All ri...
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                     <p class="hword">something</p>
#
#                                           Paragraphs4  \
# 0                                                None
# 1   <p><i>Something</i> is een van de meest gecove...
# 2   <p><a href="/wiki/George_Harrison" title="Geor...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   <p><span class="headword-line"><strong class="...
# 8   <p>Somewhere in her smile she knows<br/>\nThat...
# 9   <p>“Something” is the first <a data-api_path="...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  <p><span class="luna-label italic">Informal</s...
# 15                                               None
# 16               <p class="function-label">Adverb</p>
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p class="function-label">Synonyms &amp; Simil...
#
#                                           Paragraphs5  \
# 0                                                None
# 1                                                None
# 2   <p>The opening lyric was taken from the title ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   <p><span class="headword-line"><strong class="...
# 8   <p>You're asking me will my love grow,<br/>\nI...
# 9   <p>The song is likely about Pattie Boyd – Harr...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  <p>Dictionary.com Unabridged\nBased on the Ran...
# 15                                               None
# 16  <p class="ety-sl pb-3" data-entry-id="2">13th ...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p class="function-label">Antonyms &amp; Near ...
#
#                                           Paragraphs6  \
# 0                                                None
# 1                                                None
# 2   <p>Having begun to write love songs that were ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   <p>Something in the way she knows<br/>\nAnd al...
# 9   <p>George later denied that the song was about...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  <p><em>something</em> like fluoride, which is ...
# 15                                               None
# 16  <p>\n                    <a class="b-link" dat...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p>\n                    <a class="b-link" dat...
#
#                                           Paragraphs7  \
# 0                                                None
# 1                                                None
# 2   <p>In the version issued on the Beatles' 1969 ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                             <p></p>
# 9   <p>Well no, I didn’t [write it about her]. I j...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  <p>Citizens, perhaps, need to feel like they c...
# 15                                               None
# 16  <p class="active">\n                    <span ...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  <p class="active">\n                    <span ...
#
#                                           Paragraphs8  ...  \
# 0                                                None  ...
# 1                                                None  ...
# 2   <p>Leng considers that, lyrically and musicall...  ...
# 3                                                None  ...
# 4                                                None  ...
# 5                                                None  ...
# 6                                                None  ...
# 7                                                None  ...
# 8       <p>B-side, in custom Apple Records sleeve</p>  ...
# 9   <p>The song was released on a single with “Com...  ...
# 10                                               None  ...
# 11                                               None  ...
# 12                                               None  ...
# 13                                               None  ...
# 14  <p>Why would “they” want to crush him just for...  ...
# 15                                               None  ...
# 16  <p>\n                    <a class="b-link" dat...  ...
# 17                                               None  ...
# 18                                               None  ...
# 19                                               None  ...
# 20                                               None  ...
# 21                                               None  ...
# 22  <p>\n                    <a class="b-link" dat...  ...
#
#                                          Paragraphs57  \
# 0                                                None
# 1                                                None
# 2   <p>In honour of Harrison's fondness for the in...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs58  \
# 0                                                None
# 1                                                None
# 2   <p><a href="/wiki/Bob_Dylan" title="Bob Dylan"...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs59  \
# 0                                                None
# 1                                                None
# 2   <p>Harrison played "Something" at the two <a c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs60  \
# 0                                                None
# 1                                                None
# 2   <p>Harrison included "Something" in all of his...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs61  \
# 0                                                None
# 1                                                None
# 2   <p>A version from Harrison's December 1991 tou...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs62  \
# 0                                                None
# 1                                                None
# 2   <p>According to <a href="/wiki/Walter_Everett_...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                    Paragraphs63                          Paragraphs64  \
# 0                          None                                  None
# 1                          None                                  None
# 2   <p><b>The Beatles</b>\n</p>  <p><b>Additional musicians</b>\n</p>
# 3                          None                                  None
# 4                          None                                  None
# 5                          None                                  None
# 6                          None                                  None
# 7                          None                                  None
# 8                          None                                  None
# 9                          None                                  None
# 10                         None                                  None
# 11                         None                                  None
# 12                         None                                  None
# 13                         None                                  None
# 14                         None                                  None
# 15                         None                                  None
# 16                         None                                  None
# 17                         None                                  None
# 18                         None                                  None
# 19                         None                                  None
# 20                         None                                  None
# 21                         None                                  None
# 22                         None                                  None
#
#                                          Paragraphs65 Paragraphs66
# 0                                                None         None
# 1                                                None         None
# 2   <p><small><sup>^</sup> Shipments figures based...   <p> \n</p>
# 3                                                None         None
# 4                                                None         None
# 5                                                None         None
# 6                                                None         None
# 7                                                None         None
# 8                                                None         None
# 9                                                None         None
# 10                                               None         None
# 11                                               None         None
# 12                                               None         None
# 13                                               None         None
# 14                                               None         None
# 15                                               None         None
# 16                                               None         None
# 17                                               None         None
# 18                                               None         None
# 19                                               None         None
# 20                                               None         None
# 21                                               None         None
# 22                                               None         None
#
# [23 rows x 68 columns]

# %% [markdown]
# Now I will drop the extra column and combine the 2 datasets with each other.

# %%
df = pd.concat([df, df_add], axis=1)
df=df.drop("List_Link",axis=1)

# %% [markdown]
# In the following I will remove every html tag from the DataFrame per column

# %%
for i in range(max_para):
    column: str =("Paragraphs")+i.__str__()
    df[column]=df[column].str.replace(r'<[^<>]*>', '', regex=True)

df
# Out:
#                                                  Link  \
# 0         https://www.youtube.com/watch?v=UelDrZ1aFeY
# 1   https://nl.wikipedia.org/wiki/Something_(The_B...
# 2   https://en.wikipedia.org/wiki/Something_(Beatl...
# 3   https://dictionary.cambridge.org/dictionary/en...
# 4         https://www.youtube.com/watch?v=VWO3nEuWo4k
# 5   https://nl.bab.la/woordenboek/engels-nederland...
# 6         https://www.youtube.com/watch?v=cNavPZ8GA6I
# 7            https://en.wiktionary.org/wiki/something
# 8                https://www.thebeatles.com/something
# 9     https://genius.com/The-beatles-something-lyrics
# 10  https://www.wordreference.com/definition/somet...
# 11  https://www.oxfordlearnersdictionaries.com/def...
# 12  https://www.mijnwoordenboek.nl/vertaal/EN/NL/s...
# 13  https://dictionary.cambridge.org/us/dictionary...
# 14        https://www.dictionary.com/browse/something
# 15        https://www.youtube.com/watch?v=uXRvmkQLyTc
# 16  https://www.merriam-webster.com/dictionary/som...
# 17  https://context.reverso.net/vertaling/engels-n...
# 18  https://www.collinsdictionary.com/dictionary/e...
# 19    https://www.britannica.com/dictionary/something
# 20        https://www.youtube.com/watch?v=MZ3Vh8jZFdE
# 21         https://prosettings.net/players/something/
# 22  https://www.merriam-webster.com/thesaurus/some...
#
#                                            Paragraphs  \
# 0                                                  []
# 1   [[[<b>Something</b>],  is een nummer van de , ...
# 2   [[\n\n\n], [", [Something], " is a song by the...
# 3                                                   0
# 4                                                  []
# 5   [[This website is using a security service to ...
# 6                                                  []
# 7   [[From , [<a class="extiw" href="https://en.wi...
# 8   [[Song], [[Release date:],  06 October 1969], ...
# 9   [[Produced by], [], [How to Format Lyrics:], [...
# 10  [[Forum discussions with the word(s) "somethin...
# 11                                                  0
# 12                                [[[<span></span>]]]
# 13                                                  0
# 14  [[some thing; a certain undetermined or unspec...
# 15                                                 []
# 16  [[something], [Adverb], [Pronoun], [before the...
# 17  [[\n          You've been denied access â IP...
# 18  [[This website is using a security service to ...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [[something\n                            , [<s...
#
#                                           Paragraphs0  \
# 0                                                None
# 1   Something is een nummer van de Britse groep Th...
# 2                                              \n\n\n
# 3                                                   0
# 4                                                None
# 5   This website is using a security service to pr...
# 6                                                None
# 7   From Middle English somþyng, some-thing, som t...
# 8                                                Song
# 9                                         Produced by
# 10  Forum discussions with the word(s) "something"...
# 11                                                  0
# 12
# 13                                                  0
# 14  some thing; a certain undetermined or unspecif...
# 15                                               None
# 16                                          something
# 17  \n          You've been denied access â IP b...
# 18  This website is using a security service to pr...
# 19                                               None
# 20                                               None
# 21                                               None
# 22  something\n                            1 of 2\...
#
#                                           Paragraphs1  \
# 0                                                None
# 1   De openingszin "Something in the way she moves...
# 2   "Something" is a song by the English rock band...
# 3                                                None
# 4                                                None
# 5   You can email the site owner to let them know ...
# 6                                                None
# 7                    something (indefinite pronoun)\n
# 8                       Release date: 06 October 1969
# 9
# 10  In other languages: Spanish | French | Italian...
# 11                                               None
# 12                                               None
# 13                                               None
# 14  an additional amount, as of cents or minutes, ...
# 15                                               None
# 16                                             Adverb
# 17  \n          Votre accÃ¨s a Ã©tÃ© bloquÃ©\n    ...
# 18  You can email the site owner to let them know ...
# 19                                               None
# 20                                               None
# 21                                               None
# 22                       Synonyms &amp; Similar Words
#
#                                           Paragraphs2  \
# 0                                                None
# 1   Het lied werd door Harrison geschreven als een...
# 2   The track is generally considered a love song ...
# 3                                                None
# 4                                                None
# 5   \n    Cloudflare Ray ID: 863378d18de166a5\n   ...
# 6                                                None
# 7                        something (not comparable)\n
# 8
# 9                               How to Format Lyrics:
# 10  \n                \n                \n        ...
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Informal. a person or thing of some value or c...
# 15                                               None
# 16                                            Pronoun
# 17  Developed by Prompsit Language Engineering for...
# 18  \n    Cloudflare Ray ID: 8633790ba93a656b\n   ...
# 19                                               None
# 20                                               None
# 21                                               None
# 22                       Antonyms &amp; Near Antonyms
#
#                                           Paragraphs3  \
# 0                                                None
# 1   De bijbehorende promotieclip is vlak na de laa...
# 2   "Something" received the Ivor Novello Award fo...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                        something (not comparable)\n
# 8   Something in the way she moves\nAttracts me li...
# 9   To learn more, check out our transcription gui...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14          in some degree; to some extent; somewhat.
# 15                                               None
# 16  before the 12th century, in the meaning define...
# 17       Â© 2017 Softissimo Inc. All rights reserved.
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                          something
#
#                                           Paragraphs4  \
# 0                                                None
# 1   Something is een van de meest gecoverde Beatle...
# 2   George Harrison began writing "Something" in S...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   something (third-person singular simple presen...
# 8   Somewhere in her smile she knows\nThat I don't...
# 9   “Something” is the first George Harrison penne...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Informal. to a high or extreme degree; quite: ...
# 15                                               None
# 16                                             Adverb
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                       Synonyms &amp; Similar Words
#
#                                           Paragraphs5  \
# 0                                                None
# 1                                                None
# 2   The opening lyric was taken from the title of ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                     something (plural somethings)\n
# 8   You're asking me will my love grow,\nI don't k...
# 9   The song is likely about Pattie Boyd – Harriso...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Dictionary.com Unabridged\nBased on the Random...
# 15                                               None
# 16    13th century, in the meaning defined at sense 1
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                       Antonyms &amp; Near Antonyms
#
#                                           Paragraphs6  \
# 0                                                None
# 1                                                None
# 2   Having begun to write love songs that were dir...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   Something in the way she knows\nAnd all I have...
# 9    George later denied that the song was about her.
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  something like fluoride, which is too small fo...
# 15                                               None
# 16  \n                    somesthetic receptor\n  ...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22    \n                    someone\n
#
#                                           Paragraphs7  ...  \
# 0                                                None  ...
# 1                                                None  ...
# 2   In the version issued on the Beatles' 1969 alb...  ...
# 3                                                None  ...
# 4                                                None  ...
# 5                                                None  ...
# 6                                                None  ...
# 7                                                None  ...
# 8                                                      ...
# 9   Well no, I didn’t [write it about her]. I just...  ...
# 10                                               None  ...
# 11                                               None  ...
# 12                                               None  ...
# 13                                               None  ...
# 14  Citizens, perhaps, need to feel like they can ...  ...
# 15                                               None  ...
# 16  \n                    something\n                  ...
# 17                                               None  ...
# 18                                               None  ...
# 19                                               None  ...
# 20                                               None  ...
# 21                                               None  ...
# 22  \n                    something\n                  ...
#
#                                          Paragraphs57  \
# 0                                                None
# 1                                                None
# 2   In honour of Harrison's fondness for the instr...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs58  \
# 0                                                None
# 1                                                None
# 2   Bob Dylan also played the song live during his...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs59  \
# 0                                                None
# 1                                                None
# 2   Harrison played "Something" at the two Concert...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs60  \
# 0                                                None
# 1                                                None
# 2   Harrison included "Something" in all of his su...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs61  \
# 0                                                None
# 1                                                None
# 2   A version from Harrison's December 1991 tour o...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                          Paragraphs62   Paragraphs63  \
# 0                                                None           None
# 1                                                None           None
# 2   According to Walter Everett,[52] Bruce Spizer[...  The Beatles\n
# 3                                                None           None
# 4                                                None           None
# 5                                                None           None
# 6                                                None           None
# 7                                                None           None
# 8                                                None           None
# 9                                                None           None
# 10                                               None           None
# 11                                               None           None
# 12                                               None           None
# 13                                               None           None
# 14                                               None           None
# 15                                               None           None
# 16                                               None           None
# 17                                               None           None
# 18                                               None           None
# 19                                               None           None
# 20                                               None           None
# 21                                               None           None
# 22                                               None           None
#
#               Paragraphs64                                       Paragraphs65  \
# 0                     None                                               None
# 1                     None                                               None
# 2   Additional musicians\n  ^ Shipments figures based on certification alo...
# 3                     None                                               None
# 4                     None                                               None
# 5                     None                                               None
# 6                     None                                               None
# 7                     None                                               None
# 8                     None                                               None
# 9                     None                                               None
# 10                    None                                               None
# 11                    None                                               None
# 12                    None                                               None
# 13                    None                                               None
# 14                    None                                               None
# 15                    None                                               None
# 16                    None                                               None
# 17                    None                                               None
# 18                    None                                               None
# 19                    None                                               None
# 20                    None                                               None
# 21                    None                                               None
# 22                    None                                               None
#
#    Paragraphs66
# 0          None
# 1          None
# 2            \n
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None
# 20         None
# 21         None
# 22         None
#
# [23 rows x 69 columns]

# %% [markdown]
# ## What's next?
# Now comes the part where it needs to be cleaned and send to something.
#
# ## Improvements
#
# - Connect to the platform and get the search part.
# - Remove links that will not deliver anything useful.
# - Have a max size of the paragraphs
# - Look into time improvements
