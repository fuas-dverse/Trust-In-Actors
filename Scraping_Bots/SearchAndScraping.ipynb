# %% [markdown]
# # Search and Scraping

# %% [markdown]
# The imports below are:
# - bs4 (a.k.a. BeautifulSoup) for getting the html from the websites
# - requests for the searching part on the internet

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Search

# %% [markdown]
# As you can see below it requests an input for the search query.
# For now this is just the input method so you can manually search for something and see if it works

# %%
url = "https://www.bing.com/search?q="+input()
print(url)
page = requests.get(url)

soup = BeautifulSoup(page.text,"html")
# Out:
# https://www.bing.com/search?q=mastodon

# %% [markdown]
# Bing works with links that are coupled to the H2 html tag.
# So if we get everything related to the H2 and then search for the a html tag within we can see if its a link or not.

# %%
BingLinks= soup.find_all("h2")
links =[]

for link in BingLinks:
    a =link.find("a",href=True)
    href = a['href']
    links.append(href)

# %% [markdown]
# Here below we can which links it found with the Bing search engine.

# %%
links
# Out:
# ['https://mastodon.social/',
#  'https://joinmastodon.org/nl-NL',
#  'https://joinmastodon.org/',
#  'https://mastodon.nl/',
#  'https://en.wikipedia.org/wiki/Mastodon_(social_network)',
#  'https://joinmastodon.org/nl-NL/servers',
#  'https://nl.wikipedia.org/wiki/Mastodon_(software)',
#  'https://joinmastodon.org/nl-NL/apps',
#  'https://joinmastodon.org/about',
#  'https://joinmastodon.org/servers',
#  'https://techcrunch.com/2023/07/24/what-is-mastodon/',
#  'https://www.consumentenbond.nl/internet-privacy/mastodon',
#  'https://androidworld.nl/tips/mastodon-voor-beginners-uitleg',
#  'https://mastodon.social/about',
#  'https://social.overheid.nl/',
#  'https://mastodon.help/',
#  'https://joinmastodon.org/apps',
#  'https://www.dutchcowboys.nl/socialmedia/wat-is-mastodon-en-waarom-praat-iedereen-erover',
#  'https://github.com/mastodon/mastodon',
#  'https://mastodon.nl/@nrc_nl',
#  'https://www.vrt.be/vrtnws/nl/2022/11/01/mastodon-twitter/',
#  'https://nl.wikipedia.org/wiki/Mastodon',
#  'https://en.wikipedia.org/wiki/Mastodon']

# %% [markdown]
# Now I'm going to make a matrix of links and the found paragraphs within these websites.
# I have chosen to search on the `p` html tag because most websites will have their text inside this tag.

# %%
paragraphs =[['0' for x in range(2)] for y in range(len(links)) ]

# %% [markdown]
# ## Scraper

# %% [markdown]
# Now we are going to scrape through every website we can find.
# Hereby we need to add some extra imports these being:
# - ConnectTimeout as sometimes you can't load the website.
# - TooManyRedirects if the page redirects to another page but the bot doesn't follow easily.
#
# I also have a general exception catcher if something does go wrong it will catch it.

# %%
from http.client import RemoteDisconnected
from requests import ConnectTimeout, TooManyRedirects


i=0
for link in links:
    print(link)
    try:
        page = requests.get(link,allow_redirects=True,timeout=100)
        soup = BeautifulSoup(page.text,"html")
        ps =soup.find_all("p")
        paragraphs[i][1] =ps
    except TooManyRedirects:
        print("Failed for ",link)
    except ConnectTimeout:
        print("Failed for ",link)
    except Exception as e:
        print("Unknown error, for ",link)
    finally:
        paragraphs[i][0] =link
        i=i+1
# Out:
# https://mastodon.social/
# https://joinmastodon.org/nl-NL
# https://joinmastodon.org/
# https://mastodon.nl/
# https://en.wikipedia.org/wiki/Mastodon_(social_network)
# https://joinmastodon.org/nl-NL/servers
# https://nl.wikipedia.org/wiki/Mastodon_(software)
# https://joinmastodon.org/nl-NL/apps
# https://joinmastodon.org/about
# https://joinmastodon.org/servers
# https://techcrunch.com/2023/07/24/what-is-mastodon/
# https://www.consumentenbond.nl/internet-privacy/mastodon
# https://androidworld.nl/tips/mastodon-voor-beginners-uitleg
# https://mastodon.social/about
# https://social.overheid.nl/
# https://mastodon.help/
# https://joinmastodon.org/apps
# https://www.dutchcowboys.nl/socialmedia/wat-is-mastodon-en-waarom-praat-iedereen-erover
# https://github.com/mastodon/mastodon
# https://mastodon.nl/@nrc_nl
# https://www.vrt.be/vrtnws/nl/2022/11/01/mastodon-twitter/
# https://nl.wikipedia.org/wiki/Mastodon
# https://en.wikipedia.org/wiki/Mastodon

# %% [markdown]
# ### Making into a DataFrame
# I want to make it into a DataFrame so it will be easier to manipulate and transform it to other things such as a csv file.
# For this I will use pandas as its one of the well known tools to make DataFrames with.
#
# I also import warnings because I needed to ignore a warning of pandas because I didn't find an easier way of doing something.
# More information later down in a block where it happens

# %%
import pandas as pd
import warnings

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
df = pd.DataFrame(columns=["Link","Paragraphs"],data=paragraphs)
df
# Out:
#                                                  Link  \
# 0                            https://mastodon.social/
# 1                      https://joinmastodon.org/nl-NL
# 2                           https://joinmastodon.org/
# 3                                https://mastodon.nl/
# 4   https://en.wikipedia.org/wiki/Mastodon_(social...
# 5              https://joinmastodon.org/nl-NL/servers
# 6   https://nl.wikipedia.org/wiki/Mastodon_(software)
# 7                 https://joinmastodon.org/nl-NL/apps
# 8                      https://joinmastodon.org/about
# 9                    https://joinmastodon.org/servers
# 10  https://techcrunch.com/2023/07/24/what-is-mast...
# 11  https://www.consumentenbond.nl/internet-privac...
# 12  https://androidworld.nl/tips/mastodon-voor-beg...
# 13                      https://mastodon.social/about
# 14                        https://social.overheid.nl/
# 15                             https://mastodon.help/
# 16                      https://joinmastodon.org/apps
# 17  https://www.dutchcowboys.nl/socialmedia/wat-is...
# 18               https://github.com/mastodon/mastodon
# 19                        https://mastodon.nl/@nrc_nl
# 20  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 21             https://nl.wikipedia.org/wiki/Mastodon
# 22             https://en.wikipedia.org/wiki/Mastodon
#
#                                            Paragraphs
# 0                                                  []
# 1   [[Jouw tijdlijn zou vol moeten staan met wat v...
# 2   [[Your home feed should be filled with what ma...
# 3                                                  []
# 4   [[\n], [[Mastodon],  is a , [free and open-sou...
# 5   [[Mastodon is niet één website. Om het te gebr...
# 6   [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 7   [[De beste manier om aan de slag te gaan met M...
# 8   [[Free, open-source decentralized social media...
# 9   [[Mastodon is not a single website. To use it,...
# 10  [[As Twitter users fret over the , [direction]...
# 11  [[Wanneer je onze website bezoekt kunnen we in...
# 12  [[\n                                    , [\n ...
# 13                                                 []
# 14                                                 []
# 15  [[Hello :-), [], After about two months since ...
# 16  [[The best way to get started with Mastodon is...
# 17  [[Wat Telegram is voor WhatsApp, dat is , [Mas...
# 18  [[We read every piece of feedback, and take yo...
# 19                                                 []
# 20  [["Mastodon" wordt door sommigen naar voren ge...
# 21  [[[Mastodon],  kan verwijzen naar:\n], [[], \n...
# 22  [[\n], [A , [mastodon],  (, [<a class="extiw" ...

# %% [markdown]
# In the block below I search for the longest length of paragraphs that is inside of the DataFrame currently.

# %%
max_para: int = 0


for i in range(df["Paragraphs"].__len__()):
    x =len(df["Paragraphs"][i])
    if(max_para < x):
        max_para =x 

print(max_para)
# Out:
# 131

# %% [markdown]
# Now in the following block I will make the columns for where the paragraphs will be separated.

# %%
df_add = pd.DataFrame({"List_Link": df["Paragraphs"]})

for x in range(max_para):
    column: str =("Paragraphs")+x.__str__()
    df_add.loc[:,column] = None

# %% [markdown]
# In this block I will do something that is not recommended such as doing a double for loop where I iterate through the DataFrame so I can add the paragraph at the correct place in the DataFrame column and row

# %%
x=0
for ps in df["Paragraphs"]:   
   n=0
   for p in ps:
      column: str =("Paragraphs")+n.__str__()
      # print(column)
      df_add[column][x] = p.__str__()
      n=n+1
   x=x+1

df_add
# Out:
#                                             List_Link  \
# 0                                                  []
# 1   [[Jouw tijdlijn zou vol moeten staan met wat v...
# 2   [[Your home feed should be filled with what ma...
# 3                                                  []
# 4   [[\n], [[Mastodon],  is a , [free and open-sou...
# 5   [[Mastodon is niet één website. Om het te gebr...
# 6   [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 7   [[De beste manier om aan de slag te gaan met M...
# 8   [[Free, open-source decentralized social media...
# 9   [[Mastodon is not a single website. To use it,...
# 10  [[As Twitter users fret over the , [direction]...
# 11  [[Wanneer je onze website bezoekt kunnen we in...
# 12  [[\n                                    , [\n ...
# 13                                                 []
# 14                                                 []
# 15  [[Hello :-), [], After about two months since ...
# 16  [[The best way to get started with Mastodon is...
# 17  [[Wat Telegram is voor WhatsApp, dat is , [Mas...
# 18  [[We read every piece of feedback, and take yo...
# 19                                                 []
# 20  [["Mastodon" wordt door sommigen naar voren ge...
# 21  [[[Mastodon],  kan verwijzen naar:\n], [[], \n...
# 22  [[\n], [A , [mastodon],  (, [<a class="extiw" ...
#
#                                           Paragraphs0  \
# 0                                                None
# 1   <p class="sh1 mb-11 max-w-[50ch]">Jouw tijdlij...
# 2   <p class="sh1 mb-11 max-w-[50ch]">Your home fe...
# 3                                                None
# 4                      <p class="mw-empty-elt">\n</p>
# 5   <p class="sh1 mb-14 max-w-[36ch]">Mastodon is ...
# 6   <p><b>Android:</b> 2.3.0 <span style="font-siz...
# 7   <p class="sh1">De beste manier om aan de slag ...
# 8   <p class="sh1">Free, open-source decentralized...
# 9   <p class="sh1 mb-14 max-w-[36ch]">Mastodon is ...
# 10  <p id="speakable-summary">As Twitter users fre...
# 11  <p>Wanneer je onze website bezoekt kunnen we i...
# 12  <p class="lg:hidden flex items-center mt-2 spa...
# 13                                               None
# 14                                               None
# 15  <p class="fp">Hello :-)<br/>After about two mo...
# 16  <p class="sh1">The best way to get started wit...
# 17  <p>Wat Telegram is voor WhatsApp, dat is <a hr...
# 18  <p>We read every piece of feedback, and take y...
# 19                                               None
# 20  <p>"Mastodon" wordt door sommigen naar voren g...
# 21       <p><b>Mastodon</b> kan verwijzen naar:\n</p>
# 22                     <p class="mw-empty-elt">\n</p>
#
#                                           Paragraphs1  \
# 0                                                None
# 1   <p class="sh1 mb-8 text-gray-1">Je weet zelf h...
# 2   <p class="sh1 mb-8 text-gray-1">You know best ...
# 3                                                None
# 4   <p><b>Mastodon</b> is a <a href="/wiki/Free_an...
# 5   <p class="b2 text-gray-1">De eerste stap is te...
# 6   <p><b>Mastodon</b> is sinds 2016 <a href="/wik...
# 7   <p class="mt-2 max-w-[28ch]">Vrij, open source...
# 8   <p class="b1 mb-4"><strong>Mastodon gGmbH is a...
# 9   <p class="b2 text-gray-1">The first step is de...
# 10  <p>Since October 27, when the SpaceX and Tesla...
# 11  <p class="flex-col flex flex-wrap items-center...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="fp">Mastodon is a <a href="https://e...
# 16  <p class="mt-2 max-w-[28ch]">Free, open-source...
# 17  <p>Ten eerste is Mastodon niet nieuw. Het is n...
# 18  <p class="text-small color-fg-muted">\n       ...
# 19                                               None
# 20  <p>Waarover gaat het? Techmiljardair Elon Musk...
# 21                         <p><br clear="all"/>\n</p>
# 22  <p>A <b>mastodon</b> (<i lang="grc"><a class="...
#
#                                           Paragraphs2  \
# 0                                                None
# 1   <p class="sh1 mb-8 text-gray-1">Mastodon biedt...
# 2   <p class="sh1 mb-8 text-gray-1">Mastodon provi...
# 3                                                None
# 4   <p>Each user is a member of a specific Mastodo...
# 5   <p class="b2 text-gray-1">Met een account op j...
# 6   <p>Een Mastodon-site is te vergelijken met <a ...
# 7                                                None
# 8   <p class="b1 mb-4">Believing that instant glob...
# 9   <p class="b2 text-gray-1">With an account on y...
# 10  <p>If you’re a Twitter purist who likes to use...
# 11  <p>Mastodon lijkt nogal op Twitter. Je deelt o...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="p">But Mastodon is not a Twitter clo...
# 16                                               None
# 17  <p>Het voordeel van Mastodon boven <a href="ht...
# 18  <p class="f4 mb-3">\n        Your self-hosted,...
# 19                                               None
# 20  <p>Platformen met minimale moderatie worden he...
# 21  <p><small>Op deze pagina staat een uitleg van ...
# 22  <p><i>M. americanum</i>, known as an "American...
#
#                                           Paragraphs3  \
# 0                                                None
# 1   <p class="sh1 mb-8 text-gray-1">Mastodon legt ...
# 2   <p class="sh1 mb-8 text-gray-1">Mastodon puts ...
# 3                                                None
# 4   <p>Mastodon was created by <a href="/wiki/Euge...
# 5   <p class="b2 text-gray-1">Zoek je een andere s...
# 6   <p>Het netwerk kreeg meer bekendheid na de ove...
# 7                                                None
# 8   <p class="b1 mb-4">The first public launch occ...
# 9   <p class="b2 text-gray-1">Find a different ser...
# 10  <p>Mastodon was founded in 2016 by German soft...
# 11  <p>Je ‘volgt’ interessante andere gebruikers z...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="p">This page, that was last updated ...
# 16                                               None
# 17  <p>Je ziet overigens wel berichten die van and...
# 18  <p dir="auto"><a href="https://github.com/mast...
# 19                                               None
# 20  <p>Alleen is dat niet ideaal op het internet. ...
# 21                                               None
# 22  <p>Taxonomically, <i>M. americanum</i> was fir...
#
#                                           Paragraphs4  \
# 0                                                None
# 1   <p class="sh1 mb-8 text-gray-1">Mastodon onder...
# 2   <p class="sh1 mb-8 text-gray-1">Mastodon suppo...
# 3                                                None
# 4   <p>The project is maintained by German <a href...
# 5   <p class="b2 text-gray-1">We hebben geen contr...
# 6   <p>Net zoals Twitter gebruikt de Mastodon web-...
# 7                                                None
# 8   <p class="b1 mb-6">The project was officially ...
# 9   <p class="b2 text-gray-1">We can't control the...
# 10  <p>“Unlike the past 5 years that I’ve been run...
# 11  <p>Er is wel een belangrijk verschil met Twitt...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="p">The site also features <a href="i...
# 16                                               None
# 17  <p>Heb je dus geen behoefte aan beledigingen e...
# 18  <p dir="auto">Mastodon is a <strong>free, open...
# 19                                               None
# 20  <p>Ook het wispelturige karakter van Musk spee...
# 21                                               None
# 22  <p>As a member of the Mammutidae, it is define...
#
#                                           Paragraphs5  \
# 0                                                None
# 1   <p class="b2 text-gray-1">Directe wereldwijde ...
# 2   <p class="b2 text-gray-1">Instant global commu...
# 3                                                None
# 4   <p>Mastodon servers run social networking soft...
# 5   <p class="b2 mb-8 text-gray-1">Alle hier verme...
# 6   <p>Mastodongebruikers kunnen net zoals op ande...
# 7                                                None
# 8   <p class="b1 mb-6"><a class="inline-flex items...
# 9   <p class="b2 mb-8 text-gray-1">All servers lis...
# 10  <p>Mastodon might look like a Twitter clone at...
# 11  <p>Eind 2022 waren er maandelijks ruim 2,4 mil...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="rfp">There is no such thing as <em>a...
# 16                                               None
# 17  <p>Het is nog onduidelijk of Twitter straks in...
# 18  <p dir="auto">Click below to <strong>learn mor...
# 19                                               None
# 20  <p><b>Beluister hier het gesprek in "De ochten...
# 21                                               None
# 22  <p>Mastodons disappeared along with many other...
#
#                                           Paragraphs6  \
# 0                                                None
# 1   <p class="b2 text-gray-1">Mastodon is vrije en...
# 2   <p class="b2 text-gray-1">Mastodon is free and...
# 3                                                None
# 4   <p>Since version 2.9.0, Mastodon has offered a...
# 5   <p class="b3 mb-4 text-gray-2">Waar de aanbied...
# 6   <p>Openbare tijdlijnen kunnen ook op taal gefi...
# 7                                                None
# 8   <p class="sh1 mb-8 text-gray-2">What others wr...
# 9   <p class="b3 mb-4 text-gray-2">Where the provi...
# 10  <p>When you first create your account, you cho...
# 11  <p>Hoe gebruik je het, in vogelvlucht? Je maak...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="p">Every Instance has its own indepe...
# 16                                               None
# 17  <p>Mastodon is op dit moment overigens nog vri...
# 18  <p dir="auto"><a href="https://www.youtube.com...
# 19                                               None
# 20  <p>Veel Twittergebruikers zouden daarom een ov...
# 21                                               None
# 22  <p>In a letter dating to 1813, <a href="/wiki/...
#
#                                           Paragraphs7  \
# 0                                                None
# 1   <p class="b2 text-gray-1">We respecteren jouw ...
# 2   <p class="b2 text-gray-1">We respect your agen...
# 3                                                None
# 4   <p>Users join a specific Mastodon server, rath...
# 5   <p class="b3 mb-4 text-gray-2">Sommige aanbied...
# 6   <p>Als gevolg van de <a href="/wiki/Open_stand...
# 7                                                None
# 8   <p class="mt-2 max-w-[28ch]">Free, open-source...
# 9   <p class="b3 mb-4 text-gray-2">Some providers ...
# 10  <p>Mastodon users generally refer to individua...
# 11  <p>Het streven van Mastodon is goed. Door de t...
# 12  <p class="editor-paragraph mb-4 text-base text...
# 13                                               None
# 14                                               None
# 15  <p class="p">From any Instance it is possible ...
# 16                                               None
# 17  <p>Het Duitse Mastodon moet echter nog wel aan...
# 18  <p dir="auto"><a href="/mastodon/mastodon/blob...
# 19                                               None
# 20  <p>Het is een project dat is opgezet door vrij...
# 21                                               None
# 22  <p>Abeel reported in a later that he went to t...
#
#                                           Paragraphs8  ...  \
# 0                                                None  ...
# 1   <p class="b2 text-gray-1">Mastodon is gebouwd ...  ...
# 2   <p class="b2 text-gray-1">Built on open web pr...  ...
# 3                                                None  ...
# 4   <p>Mastodon includes a number of specific priv...  ...
# 5   <p class="b3 mt-4 text-gray-2"><span class="in...  ...
# 6   <p>Het maakt net zoals bij e-mail in principe ...  ...
# 7                                                None  ...
# 8                                                None  ...
# 9   <p class="b3 mt-4 text-gray-2"><span class="in...  ...
# 10  <p>Choosing which server to register your acco...  ...
# 11  <p>Mastodon heeft goede kans om door te groeie...  ...
# 12  <p class="editor-paragraph mb-4 text-base text...  ...
# 13                                               None  ...
# 14                                               None  ...
# 15  <p class="p">Those who administer an Instance ...  ...
# 16                                               None  ...
# 17  <p>Bovendien is het misschien lullig, maar Mas...  ...
# 18  <p dir="auto">It doesn't have to be Mastodon; ...  ...
# 19                                               None  ...
# 20  <p>"Het lijkt op het eerste zicht wel wat op T...  ...
# 21                                               None  ...
# 22  <p>In 1739, a French military expedition under...  ...
#
#                                         Paragraphs121  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="rfp">Or, if you just want to follow ...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs122  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="rfp">This will cause a popup menu to...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs123  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="rfp">Once you enter your <a href="#M...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs124  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="rfp">That’s it! Now you can open the...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs125  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p><img alt="A screenshot showing a Mastodon I...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs126  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="fp">Mastodon is by far the most wide...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs127  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="p">At the same time, however, its de...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs128  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="p">Moreover, the implementation of c...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs129  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="p">Finally, to make the current tren...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs130
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  <p class="p">We think that in a social context...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
# [23 rows x 132 columns]

# %% [markdown]
# Now I will drop the extra column and combine the 2 datasets with each other.

# %%
df = pd.concat([df, df_add], axis=1)
df=df.drop("List_Link",axis=1)

# %% [markdown]
# In the following I will remove every html tag from the DataFrame per column

# %%
for i in range(max_para):
    column: str =("Paragraphs")+i.__str__()
    df[column]=df[column].str.replace(r'<[^<>]*>', '', regex=True)

df
# Out:
#                                                  Link  \
# 0                            https://mastodon.social/
# 1                      https://joinmastodon.org/nl-NL
# 2                           https://joinmastodon.org/
# 3                                https://mastodon.nl/
# 4   https://en.wikipedia.org/wiki/Mastodon_(social...
# 5              https://joinmastodon.org/nl-NL/servers
# 6   https://nl.wikipedia.org/wiki/Mastodon_(software)
# 7                 https://joinmastodon.org/nl-NL/apps
# 8                      https://joinmastodon.org/about
# 9                    https://joinmastodon.org/servers
# 10  https://techcrunch.com/2023/07/24/what-is-mast...
# 11  https://www.consumentenbond.nl/internet-privac...
# 12  https://androidworld.nl/tips/mastodon-voor-beg...
# 13                      https://mastodon.social/about
# 14                        https://social.overheid.nl/
# 15                             https://mastodon.help/
# 16                      https://joinmastodon.org/apps
# 17  https://www.dutchcowboys.nl/socialmedia/wat-is...
# 18               https://github.com/mastodon/mastodon
# 19                        https://mastodon.nl/@nrc_nl
# 20  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 21             https://nl.wikipedia.org/wiki/Mastodon
# 22             https://en.wikipedia.org/wiki/Mastodon
#
#                                            Paragraphs  \
# 0                                                  []
# 1   [[Jouw tijdlijn zou vol moeten staan met wat v...
# 2   [[Your home feed should be filled with what ma...
# 3                                                  []
# 4   [[\n], [[Mastodon],  is a , [free and open-sou...
# 5   [[Mastodon is niet één website. Om het te gebr...
# 6   [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 7   [[De beste manier om aan de slag te gaan met M...
# 8   [[Free, open-source decentralized social media...
# 9   [[Mastodon is not a single website. To use it,...
# 10  [[As Twitter users fret over the , [direction]...
# 11  [[Wanneer je onze website bezoekt kunnen we in...
# 12  [[\n                                    , [\n ...
# 13                                                 []
# 14                                                 []
# 15  [[Hello :-), [], After about two months since ...
# 16  [[The best way to get started with Mastodon is...
# 17  [[Wat Telegram is voor WhatsApp, dat is , [Mas...
# 18  [[We read every piece of feedback, and take yo...
# 19                                                 []
# 20  [["Mastodon" wordt door sommigen naar voren ge...
# 21  [[[Mastodon],  kan verwijzen naar:\n], [[], \n...
# 22  [[\n], [A , [mastodon],  (, [<a class="extiw" ...
#
#                                           Paragraphs0  \
# 0                                                None
# 1   Jouw tijdlijn zou vol moeten staan met wat voo...
# 2   Your home feed should be filled with what matt...
# 3                                                None
# 4                                                  \n
# 5   Mastodon is niet één website. Om het te gebrui...
# 6   Android: 2.3.0 (13 februari 2024)[3] \niOS: 1....
# 7   De beste manier om aan de slag te gaan met Mas...
# 8        Free, open-source decentralized social media
# 9   Mastodon is not a single website. To use it, y...
# 10  As Twitter users fret over the direction that ...
# 11  Wanneer je onze website bezoekt kunnen we info...
# 12  \n                                    \n      ...
# 13                                               None
# 14                                               None
# 15  Hello :-)After about two months since we repla...
# 16  The best way to get started with Mastodon is t...
# 17  Wat Telegram is voor WhatsApp, dat is Mastodon...
# 18  We read every piece of feedback, and take your...
# 19                                               None
# 20  "Mastodon" wordt door sommigen naar voren gesc...
# 21                     Mastodon kan verwijzen naar:\n
# 22                                                 \n
#
#                                           Paragraphs1  \
# 0                                                None
# 1   Je weet zelf het beste wat je op jouw tijdlijn...
# 2   You know best what you want to see on your hom...
# 3                                                None
# 4   Mastodon is a free and open-source software fo...
# 5   De eerste stap is te bepalen op welke server j...
# 6   Mastodon is sinds 2016 opensourcesoftware om z...
# 7   Vrij, open source gedecentraliseerd sociaal me...
# 8   Mastodon gGmbH is a non-profit from Germany th...
# 9   The first step is deciding which server you’d ...
# 10  Since October 27, when the SpaceX and Tesla CE...
# 11  Peter Kulche   Expert ElektronicaBijgewerkt op...
# 12  \n    Mastodon is ineens volop in het nieuws. ...
# 13                                               None
# 14                                               None
# 15  Mastodon is a Free and Open Source microbloggi...
# 16  Free, open-source decentralized social media p...
# 17  Ten eerste is Mastodon niet nieuw. Het is niet...
# 18  \n            To see all available qualifiers,...
# 19                                               None
# 20  Waarover gaat het? Techmiljardair Elon Musk he...
# 21                                                 \n
# 22  A mastodon (mastós 'breast' + odoús 'tooth') i...
#
#                                           Paragraphs2  \
# 0                                                None
# 1   Mastodon biedt je een unieke mogelijkheid om j...
# 2   Mastodon provides you with a unique possibilit...
# 3                                                None
# 4   Each user is a member of a specific Mastodon s...
# 5   Met een account op jouw server kun je elke and...
# 6   Een Mastodon-site is te vergelijken met Twitte...
# 7                                                None
# 8   Believing that instant global communications w...
# 9   With an account on your server, you can follow...
# 10  If you’re a Twitter purist who likes to use ba...
# 11  Mastodon lijkt nogal op Twitter. Je deelt op e...
# 12  \n    Mastodon is opensourcesoftware waarmee i...
# 13                                               None
# 14                                               None
# 15  But Mastodon is not a Twitter clone: it is str...
# 16                                               None
# 17  Het voordeel van Mastodon boven Twitter is dat...
# 18  \n        Your self-hosted, globally interconn...
# 19                                               None
# 20  Platformen met minimale moderatie worden heel ...
# 21  Op deze pagina staat een uitleg van de verschi...
# 22  M. americanum, known as an "American mastodon"...
#
#                                           Paragraphs3  \
# 0                                                None
# 1   Mastodon legt de besluitvorming weer in jouw h...
# 2   Mastodon puts decision making back in your han...
# 3                                                None
# 4   Mastodon was created by Eugen Rochko and annou...
# 5   Zoek je een andere server waar je de voorkeur ...
# 6   Het netwerk kreeg meer bekendheid na de overna...
# 7                                                None
# 8   The first public launch occurred in October 20...
# 9   Find a different server you'd prefer? With Mas...
# 10  Mastodon was founded in 2016 by German softwar...
# 11  Je ‘volgt’ interessante andere gebruikers zoda...
# 12  \n    Nee, Mastodon is in 2016 ontworpen door ...
# 13                                               None
# 14                                               None
# 15  This page, that was last updated at the end of...
# 16                                               None
# 17  Je ziet overigens wel berichten die van andere...
# 18                                               \n\n
# 19                                               None
# 20  Alleen is dat niet ideaal op het internet. "De...
# 21                                               None
# 22  Taxonomically, M. americanum was first recogni...
#
#                                           Paragraphs4  \
# 0                                                None
# 1   Mastodon ondersteunt audio-, video- en fotober...
# 2   Mastodon supports audio, video and picture pos...
# 3                                                None
# 4   The project is maintained by German non-profit...
# 5   We hebben geen controle over de servers maar w...
# 6   Net zoals Twitter gebruikt de Mastodon web-app...
# 7                                                None
# 8   The project was officially incorporated as a g...
# 9   We can't control the servers, but we can contr...
# 10  “Unlike the past 5 years that I’ve been runnin...
# 11  Er is wel een belangrijk verschil met Twitter....
# 12  \n    Nog een groot verschil met Twitter is he...
# 13                                               None
# 14                                               None
# 15  The site also features a search engine for Mas...
# 16                                               None
# 17  Heb je dus geen behoefte aan beledigingen en j...
# 18  Mastodon is a free, open-source social network...
# 19                                               None
# 20  Ook het wispelturige karakter van Musk speelt ...
# 21                                               None
# 22  As a member of the Mammutidae, it is defined b...
#
#                                           Paragraphs5  \
# 0                                                None
# 1   Directe wereldwijde communicatie is te belangr...
# 2   Instant global communication is too important ...
# 3                                                None
# 4   Mastodon servers run social networking softwar...
# 5   Alle hier vermelde servers hebben zich akkoord...
# 6   Mastodongebruikers kunnen net zoals op andere ...
# 7                                                None
# 8                                       Join the team
# 9   All servers listed here have committed to the ...
# 10  Mastodon might look like a Twitter clone at fi...
# 11  Eind 2022 waren er maandelijks ruim 2,4 miljoe...
# 12  \n    Mastodon is dus opensourcesoftware dat b...
# 13                                               None
# 14                                               None
# 15  There is no such thing as a social network cal...
# 16                                               None
# 17  Het is nog onduidelijk of Twitter straks inder...
# 18              Click below to learn more in a video:
# 19                                               None
# 20        Beluister hier het gesprek in "De ochtend":
# 21                                               None
# 22  Mastodons disappeared along with many other No...
#
#                                           Paragraphs6  \
# 0                                                None
# 1   Mastodon is vrije en opensourcesoftware. Wij g...
# 2   Mastodon is free and open-source software. We ...
# 3                                                None
# 4   Since version 2.9.0, Mastodon has offered a si...
# 5           Waar de aanbieder wettelijk is gevestigd.
# 6   Openbare tijdlijnen kunnen ook op taal gefilte...
# 7                                                None
# 8                         What others write about us.
# 9                Where the provider is legally based.
# 10  When you first create your account, you choose...
# 11  Hoe gebruik je het, in vogelvlucht? Je maakt e...
# 12  \n    Wees overigens niet bang dat je belangri...
# 13                                               None
# 14                                               None
# 15  Every Instance has its own independent server,...
# 16                                               None
# 17  Mastodon is op dit moment overigens nog vrij k...
# 18
# 19                                               None
# 20  Veel Twittergebruikers zouden daarom een overs...
# 21                                               None
# 22  In a letter dating to 1813, Edward Hyde, 3rd E...
#
#                                           Paragraphs7  ...  \
# 0                                                None  ...
# 1   We respecteren jouw handelsbekwaamheid. Jouw t...  ...
# 2   We respect your agency. Your feed is curated a...  ...
# 3                                                None  ...
# 4   Users join a specific Mastodon server, rather ...  ...
# 5   Sommige aanbieders zijn gespecialiseerd in het...  ...
# 6   Als gevolg van de open standaarden bestaan er ...  ...
# 7                                                None  ...
# 8   Free, open-source decentralized social media p...  ...
# 9   Some providers specialize in hosting accounts ...  ...
# 10  Mastodon users generally refer to individual c...  ...
# 11  Het streven van Mastodon is goed. Door de tran...  ...
# 12  \n    Wil je dus beginnen met Mastodon? Dan ku...  ...
# 13                                               None  ...
# 14                                               None  ...
# 15  From any Instance it is possible to interact w...  ...
# 16                                               None  ...
# 17  Het Duitse Mastodon moet echter nog wel aan de...  ...
# 18                                                     ...
# 19                                               None  ...
# 20  Het is een project dat is opgezet door vrijwil...  ...
# 21                                               None  ...
# 22  Abeel reported in a later that he went to the ...  ...
#
#                                         Paragraphs121  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Or, if you just want to follow the account tha...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs122  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  This will cause a popup menu to appear from wh...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs123  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Once you enter your Mastodon Address and press...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs124 Paragraphs125  \
# 0                                                None          None
# 1                                                None          None
# 2                                                None          None
# 3                                                None          None
# 4                                                None          None
# 5                                                None          None
# 6                                                None          None
# 7                                                None          None
# 8                                                None          None
# 9                                                None          None
# 10                                               None          None
# 11                                               None          None
# 12                                               None          None
# 13                                               None          None
# 14                                               None          None
# 15  That’s it! Now you can open the PeerTube accou...
# 16                                               None          None
# 17                                               None          None
# 18                                               None          None
# 19                                               None          None
# 20                                               None          None
# 21                                               None          None
# 22                                               None          None
#
#                                         Paragraphs126  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Mastodon is by far the most widely used platfo...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs127  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  At the same time, however, its development tea...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs128  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Moreover, the implementation of content views ...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs129  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Finally, to make the current trend of reproduc...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs130
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  We think that in a social context that is cult...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
# [23 rows x 133 columns]

# %% [markdown]
# ## Cleaning

# %%
for i in range(max_para):
    column: str =("Paragraphs")+i.__str__()
    df[column]=df[column].str.replace('[', '', regex=True)
    df[column]=df[column].str.replace(']', '', regex=True)
    df[column]=df[column].str.replace('', '', regex=True)
    df[column]=df[column].str.replace('&amp;', '', regex=True)
    df[column]=df[column].str.replace('\\n', '', regex=True)
df
# Out:
#                                                  Link  \
# 0                            https://mastodon.social/
# 1                      https://joinmastodon.org/nl-NL
# 2                           https://joinmastodon.org/
# 3                                https://mastodon.nl/
# 4   https://en.wikipedia.org/wiki/Mastodon_(social...
# 5              https://joinmastodon.org/nl-NL/servers
# 6   https://nl.wikipedia.org/wiki/Mastodon_(software)
# 7                 https://joinmastodon.org/nl-NL/apps
# 8                      https://joinmastodon.org/about
# 9                    https://joinmastodon.org/servers
# 10  https://techcrunch.com/2023/07/24/what-is-mast...
# 11  https://www.consumentenbond.nl/internet-privac...
# 12  https://androidworld.nl/tips/mastodon-voor-beg...
# 13                      https://mastodon.social/about
# 14                        https://social.overheid.nl/
# 15                             https://mastodon.help/
# 16                      https://joinmastodon.org/apps
# 17  https://www.dutchcowboys.nl/socialmedia/wat-is...
# 18               https://github.com/mastodon/mastodon
# 19                        https://mastodon.nl/@nrc_nl
# 20  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 21             https://nl.wikipedia.org/wiki/Mastodon
# 22             https://en.wikipedia.org/wiki/Mastodon
#
#                                            Paragraphs  \
# 0                                                  []
# 1   [[Jouw tijdlijn zou vol moeten staan met wat v...
# 2   [[Your home feed should be filled with what ma...
# 3                                                  []
# 4   [[\n], [[Mastodon],  is a , [free and open-sou...
# 5   [[Mastodon is niet één website. Om het te gebr...
# 6   [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 7   [[De beste manier om aan de slag te gaan met M...
# 8   [[Free, open-source decentralized social media...
# 9   [[Mastodon is not a single website. To use it,...
# 10  [[As Twitter users fret over the , [direction]...
# 11  [[Wanneer je onze website bezoekt kunnen we in...
# 12  [[\n                                    , [\n ...
# 13                                                 []
# 14                                                 []
# 15  [[Hello :-), [], After about two months since ...
# 16  [[The best way to get started with Mastodon is...
# 17  [[Wat Telegram is voor WhatsApp, dat is , [Mas...
# 18  [[We read every piece of feedback, and take yo...
# 19                                                 []
# 20  [["Mastodon" wordt door sommigen naar voren ge...
# 21  [[[Mastodon],  kan verwijzen naar:\n], [[], \n...
# 22  [[\n], [A , [mastodon],  (, [<a class="extiw" ...
#
#                                           Paragraphs0  \
# 0                                                None
# 1   Jouw tijdlijn zou vol moeten staan met wat voo...
# 2   Your home feed should be filled with what matt...
# 3                                                None
# 4
# 5   Mastodon is niet één website. Om het te gebrui...
# 6   Android: 2.3.0 (13 februari 2024)3 iOS: 1.5.2 ...
# 7   De beste manier om aan de slag te gaan met Mas...
# 8        Free, open-source decentralized social media
# 9   Mastodon is not a single website. To use it, y...
# 10  As Twitter users fret over the direction that ...
# 11  Wanneer je onze website bezoekt kunnen we info...
# 12                                                ...
# 13                                               None
# 14                                               None
# 15  Hello :-)After about two months since we repla...
# 16  The best way to get started with Mastodon is t...
# 17  Wat Telegram is voor WhatsApp, dat is Mastodon...
# 18  We read every piece of feedback, and take your...
# 19                                               None
# 20  "Mastodon" wordt door sommigen naar voren gesc...
# 21                       Mastodon kan verwijzen naar:
# 22
#
#                                           Paragraphs1  \
# 0                                                None
# 1   Je weet zelf het beste wat je op jouw tijdlijn...
# 2   You know best what you want to see on your hom...
# 3                                                None
# 4   Mastodon is a free and open-source software fo...
# 5   De eerste stap is te bepalen op welke server j...
# 6   Mastodon is sinds 2016 opensourcesoftware om z...
# 7   Vrij, open source gedecentraliseerd sociaal me...
# 8   Mastodon gGmbH is a non-profit from Germany th...
# 9   The first step is deciding which server you’d ...
# 10  Since October 27, when the SpaceX and Tesla CE...
# 11  Peter Kulche   Expert ElektronicaBijgewerkt op...
# 12      Mastodon is ineens volop in het nieuws. Di...
# 13                                               None
# 14                                               None
# 15  Mastodon is a Free and Open Source microbloggi...
# 16  Free, open-source decentralized social media p...
# 17  Ten eerste is Mastodon niet nieuw. Het is niet...
# 18              To see all available qualifiers, s...
# 19                                               None
# 20  Waarover gaat het? Techmiljardair Elon Musk he...
# 21
# 22  A mastodon (mastós 'breast' + odoús 'tooth') i...
#
#                                           Paragraphs2  \
# 0                                                None
# 1   Mastodon biedt je een unieke mogelijkheid om j...
# 2   Mastodon provides you with a unique possibilit...
# 3                                                None
# 4   Each user is a member of a specific Mastodon s...
# 5   Met een account op jouw server kun je elke and...
# 6   Een Mastodon-site is te vergelijken met Twitte...
# 7                                                None
# 8   Believing that instant global communications w...
# 9   With an account on your server, you can follow...
# 10  If you’re a Twitter purist who likes to use ba...
# 11  Mastodon lijkt nogal op Twitter. Je deelt op e...
# 12      Mastodon is opensourcesoftware waarmee ied...
# 13                                               None
# 14                                               None
# 15  But Mastodon is not a Twitter clone: it is str...
# 16                                               None
# 17  Het voordeel van Mastodon boven Twitter is dat...
# 18          Your self-hosted, globally interconnec...
# 19                                               None
# 20  Platformen met minimale moderatie worden heel ...
# 21  Op deze pagina staat een uitleg van de verschi...
# 22  M. americanum, known as an "American mastodon"...
#
#                                           Paragraphs3  \
# 0                                                None
# 1   Mastodon legt de besluitvorming weer in jouw h...
# 2   Mastodon puts decision making back in your han...
# 3                                                None
# 4   Mastodon was created by Eugen Rochko and annou...
# 5   Zoek je een andere server waar je de voorkeur ...
# 6   Het netwerk kreeg meer bekendheid na de overna...
# 7                                                None
# 8   The first public launch occurred in October 20...
# 9   Find a different server you'd prefer? With Mas...
# 10  Mastodon was founded in 2016 by German softwar...
# 11  Je ‘volgt’ interessante andere gebruikers zoda...
# 12      Nee, Mastodon is in 2016 ontworpen door de...
# 13                                               None
# 14                                               None
# 15  This page, that was last updated at the end of...
# 16                                               None
# 17  Je ziet overigens wel berichten die van andere...
# 18
# 19                                               None
# 20  Alleen is dat niet ideaal op het internet. "De...
# 21                                               None
# 22  Taxonomically, M. americanum was first recogni...
#
#                                           Paragraphs4  \
# 0                                                None
# 1   Mastodon ondersteunt audio-, video- en fotober...
# 2   Mastodon supports audio, video and picture pos...
# 3                                                None
# 4   The project is maintained by German non-profit...
# 5   We hebben geen controle over de servers maar w...
# 6   Net zoals Twitter gebruikt de Mastodon web-app...
# 7                                                None
# 8   The project was officially incorporated as a g...
# 9   We can't control the servers, but we can contr...
# 10  “Unlike the past 5 years that I’ve been runnin...
# 11  Er is wel een belangrijk verschil met Twitter....
# 12      Nog een groot verschil met Twitter is het ...
# 13                                               None
# 14                                               None
# 15  The site also features a search engine for Mas...
# 16                                               None
# 17  Heb je dus geen behoefte aan beledigingen en j...
# 18  Mastodon is a free, open-source social network...
# 19                                               None
# 20  Ook het wispelturige karakter van Musk speelt ...
# 21                                               None
# 22  As a member of the Mammutidae, it is defined b...
#
#                                           Paragraphs5  \
# 0                                                None
# 1   Directe wereldwijde communicatie is te belangr...
# 2   Instant global communication is too important ...
# 3                                                None
# 4   Mastodon servers run social networking softwar...
# 5   Alle hier vermelde servers hebben zich akkoord...
# 6   Mastodongebruikers kunnen net zoals op andere ...
# 7                                                None
# 8                                       Join the team
# 9   All servers listed here have committed to the ...
# 10  Mastodon might look like a Twitter clone at fi...
# 11  Eind 2022 waren er maandelijks ruim 2,4 miljoe...
# 12      Mastodon is dus opensourcesoftware dat bes...
# 13                                               None
# 14                                               None
# 15  There is no such thing as a social network cal...
# 16                                               None
# 17  Het is nog onduidelijk of Twitter straks inder...
# 18              Click below to learn more in a video:
# 19                                               None
# 20        Beluister hier het gesprek in "De ochtend":
# 21                                               None
# 22  Mastodons disappeared along with many other No...
#
#                                           Paragraphs6  \
# 0                                                None
# 1   Mastodon is vrije en opensourcesoftware. Wij g...
# 2   Mastodon is free and open-source software. We ...
# 3                                                None
# 4   Since version 2.9.0, Mastodon has offered a si...
# 5           Waar de aanbieder wettelijk is gevestigd.
# 6   Openbare tijdlijnen kunnen ook op taal gefilte...
# 7                                                None
# 8                         What others write about us.
# 9                Where the provider is legally based.
# 10  When you first create your account, you choose...
# 11  Hoe gebruik je het, in vogelvlucht? Je maakt e...
# 12      Wees overigens niet bang dat je belangrijk...
# 13                                               None
# 14                                               None
# 15  Every Instance has its own independent server,...
# 16                                               None
# 17  Mastodon is op dit moment overigens nog vrij k...
# 18
# 19                                               None
# 20  Veel Twittergebruikers zouden daarom een overs...
# 21                                               None
# 22  In a letter dating to 1813, Edward Hyde, 3rd E...
#
#                                           Paragraphs7  ...  \
# 0                                                None  ...
# 1   We respecteren jouw handelsbekwaamheid. Jouw t...  ...
# 2   We respect your agency. Your feed is curated a...  ...
# 3                                                None  ...
# 4   Users join a specific Mastodon server, rather ...  ...
# 5   Sommige aanbieders zijn gespecialiseerd in het...  ...
# 6   Als gevolg van de open standaarden bestaan er ...  ...
# 7                                                None  ...
# 8   Free, open-source decentralized social media p...  ...
# 9   Some providers specialize in hosting accounts ...  ...
# 10  Mastodon users generally refer to individual c...  ...
# 11  Het streven van Mastodon is goed. Door de tran...  ...
# 12      Wil je dus beginnen met Mastodon? Dan kun ...  ...
# 13                                               None  ...
# 14                                               None  ...
# 15  From any Instance it is possible to interact w...  ...
# 16                                               None  ...
# 17  Het Duitse Mastodon moet echter nog wel aan de...  ...
# 18                                                     ...
# 19                                               None  ...
# 20  Het is een project dat is opgezet door vrijwil...  ...
# 21                                               None  ...
# 22  Abeel reported in a later that he went to the ...  ...
#
#                                         Paragraphs121  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Or, if you just want to follow the account tha...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs122  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  This will cause a popup menu to appear from wh...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs123  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Once you enter your Mastodon Address and press...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs124 Paragraphs125  \
# 0                                                None          None
# 1                                                None          None
# 2                                                None          None
# 3                                                None          None
# 4                                                None          None
# 5                                                None          None
# 6                                                None          None
# 7                                                None          None
# 8                                                None          None
# 9                                                None          None
# 10                                               None          None
# 11                                               None          None
# 12                                               None          None
# 13                                               None          None
# 14                                               None          None
# 15  That’s it! Now you can open the PeerTube accou...
# 16                                               None          None
# 17                                               None          None
# 18                                               None          None
# 19                                               None          None
# 20                                               None          None
# 21                                               None          None
# 22                                               None          None
#
#                                         Paragraphs126  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Mastodon is by far the most widely used platfo...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs127  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  At the same time, however, its development tea...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs128  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Moreover, the implementation of content views ...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs129  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Finally, to make the current trend of reproduc...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs130
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  We think that in a social context that is cult...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
# [23 rows x 133 columns]

# %% [markdown]
# Replace the empty strings with None values so we can later delete it if necessary

# %%
df=df.replace(r'^\s*$', None, regex=True)
df
# Out:
#                                                  Link  \
# 0                            https://mastodon.social/
# 1                      https://joinmastodon.org/nl-NL
# 2                           https://joinmastodon.org/
# 3                                https://mastodon.nl/
# 4   https://en.wikipedia.org/wiki/Mastodon_(social...
# 5              https://joinmastodon.org/nl-NL/servers
# 6   https://nl.wikipedia.org/wiki/Mastodon_(software)
# 7                 https://joinmastodon.org/nl-NL/apps
# 8                      https://joinmastodon.org/about
# 9                    https://joinmastodon.org/servers
# 10  https://techcrunch.com/2023/07/24/what-is-mast...
# 11  https://www.consumentenbond.nl/internet-privac...
# 12  https://androidworld.nl/tips/mastodon-voor-beg...
# 13                      https://mastodon.social/about
# 14                        https://social.overheid.nl/
# 15                             https://mastodon.help/
# 16                      https://joinmastodon.org/apps
# 17  https://www.dutchcowboys.nl/socialmedia/wat-is...
# 18               https://github.com/mastodon/mastodon
# 19                        https://mastodon.nl/@nrc_nl
# 20  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 21             https://nl.wikipedia.org/wiki/Mastodon
# 22             https://en.wikipedia.org/wiki/Mastodon
#
#                                            Paragraphs  \
# 0                                                  []
# 1   [[Jouw tijdlijn zou vol moeten staan met wat v...
# 2   [[Your home feed should be filled with what ma...
# 3                                                  []
# 4   [[\n], [[Mastodon],  is a , [free and open-sou...
# 5   [[Mastodon is niet één website. Om het te gebr...
# 6   [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 7   [[De beste manier om aan de slag te gaan met M...
# 8   [[Free, open-source decentralized social media...
# 9   [[Mastodon is not a single website. To use it,...
# 10  [[As Twitter users fret over the , [direction]...
# 11  [[Wanneer je onze website bezoekt kunnen we in...
# 12  [[\n                                    , [\n ...
# 13                                                 []
# 14                                                 []
# 15  [[Hello :-), [], After about two months since ...
# 16  [[The best way to get started with Mastodon is...
# 17  [[Wat Telegram is voor WhatsApp, dat is , [Mas...
# 18  [[We read every piece of feedback, and take yo...
# 19                                                 []
# 20  [["Mastodon" wordt door sommigen naar voren ge...
# 21  [[[Mastodon],  kan verwijzen naar:\n], [[], \n...
# 22  [[\n], [A , [mastodon],  (, [<a class="extiw" ...
#
#                                           Paragraphs0  \
# 0                                                None
# 1   Jouw tijdlijn zou vol moeten staan met wat voo...
# 2   Your home feed should be filled with what matt...
# 3                                                None
# 4                                                None
# 5   Mastodon is niet één website. Om het te gebrui...
# 6   Android: 2.3.0 (13 februari 2024)3 iOS: 1.5.2 ...
# 7   De beste manier om aan de slag te gaan met Mas...
# 8        Free, open-source decentralized social media
# 9   Mastodon is not a single website. To use it, y...
# 10  As Twitter users fret over the direction that ...
# 11  Wanneer je onze website bezoekt kunnen we info...
# 12                                                ...
# 13                                               None
# 14                                               None
# 15  Hello :-)After about two months since we repla...
# 16  The best way to get started with Mastodon is t...
# 17  Wat Telegram is voor WhatsApp, dat is Mastodon...
# 18  We read every piece of feedback, and take your...
# 19                                               None
# 20  "Mastodon" wordt door sommigen naar voren gesc...
# 21                       Mastodon kan verwijzen naar:
# 22                                               None
#
#                                           Paragraphs1  \
# 0                                                None
# 1   Je weet zelf het beste wat je op jouw tijdlijn...
# 2   You know best what you want to see on your hom...
# 3                                                None
# 4   Mastodon is a free and open-source software fo...
# 5   De eerste stap is te bepalen op welke server j...
# 6   Mastodon is sinds 2016 opensourcesoftware om z...
# 7   Vrij, open source gedecentraliseerd sociaal me...
# 8   Mastodon gGmbH is a non-profit from Germany th...
# 9   The first step is deciding which server you’d ...
# 10  Since October 27, when the SpaceX and Tesla CE...
# 11  Peter Kulche   Expert ElektronicaBijgewerkt op...
# 12      Mastodon is ineens volop in het nieuws. Di...
# 13                                               None
# 14                                               None
# 15  Mastodon is a Free and Open Source microbloggi...
# 16  Free, open-source decentralized social media p...
# 17  Ten eerste is Mastodon niet nieuw. Het is niet...
# 18              To see all available qualifiers, s...
# 19                                               None
# 20  Waarover gaat het? Techmiljardair Elon Musk he...
# 21                                               None
# 22  A mastodon (mastós 'breast' + odoús 'tooth') i...
#
#                                           Paragraphs2  \
# 0                                                None
# 1   Mastodon biedt je een unieke mogelijkheid om j...
# 2   Mastodon provides you with a unique possibilit...
# 3                                                None
# 4   Each user is a member of a specific Mastodon s...
# 5   Met een account op jouw server kun je elke and...
# 6   Een Mastodon-site is te vergelijken met Twitte...
# 7                                                None
# 8   Believing that instant global communications w...
# 9   With an account on your server, you can follow...
# 10  If you’re a Twitter purist who likes to use ba...
# 11  Mastodon lijkt nogal op Twitter. Je deelt op e...
# 12      Mastodon is opensourcesoftware waarmee ied...
# 13                                               None
# 14                                               None
# 15  But Mastodon is not a Twitter clone: it is str...
# 16                                               None
# 17  Het voordeel van Mastodon boven Twitter is dat...
# 18          Your self-hosted, globally interconnec...
# 19                                               None
# 20  Platformen met minimale moderatie worden heel ...
# 21  Op deze pagina staat een uitleg van de verschi...
# 22  M. americanum, known as an "American mastodon"...
#
#                                           Paragraphs3  \
# 0                                                None
# 1   Mastodon legt de besluitvorming weer in jouw h...
# 2   Mastodon puts decision making back in your han...
# 3                                                None
# 4   Mastodon was created by Eugen Rochko and annou...
# 5   Zoek je een andere server waar je de voorkeur ...
# 6   Het netwerk kreeg meer bekendheid na de overna...
# 7                                                None
# 8   The first public launch occurred in October 20...
# 9   Find a different server you'd prefer? With Mas...
# 10  Mastodon was founded in 2016 by German softwar...
# 11  Je ‘volgt’ interessante andere gebruikers zoda...
# 12      Nee, Mastodon is in 2016 ontworpen door de...
# 13                                               None
# 14                                               None
# 15  This page, that was last updated at the end of...
# 16                                               None
# 17  Je ziet overigens wel berichten die van andere...
# 18                                               None
# 19                                               None
# 20  Alleen is dat niet ideaal op het internet. "De...
# 21                                               None
# 22  Taxonomically, M. americanum was first recogni...
#
#                                           Paragraphs4  \
# 0                                                None
# 1   Mastodon ondersteunt audio-, video- en fotober...
# 2   Mastodon supports audio, video and picture pos...
# 3                                                None
# 4   The project is maintained by German non-profit...
# 5   We hebben geen controle over de servers maar w...
# 6   Net zoals Twitter gebruikt de Mastodon web-app...
# 7                                                None
# 8   The project was officially incorporated as a g...
# 9   We can't control the servers, but we can contr...
# 10  “Unlike the past 5 years that I’ve been runnin...
# 11  Er is wel een belangrijk verschil met Twitter....
# 12      Nog een groot verschil met Twitter is het ...
# 13                                               None
# 14                                               None
# 15  The site also features a search engine for Mas...
# 16                                               None
# 17  Heb je dus geen behoefte aan beledigingen en j...
# 18  Mastodon is a free, open-source social network...
# 19                                               None
# 20  Ook het wispelturige karakter van Musk speelt ...
# 21                                               None
# 22  As a member of the Mammutidae, it is defined b...
#
#                                           Paragraphs5  \
# 0                                                None
# 1   Directe wereldwijde communicatie is te belangr...
# 2   Instant global communication is too important ...
# 3                                                None
# 4   Mastodon servers run social networking softwar...
# 5   Alle hier vermelde servers hebben zich akkoord...
# 6   Mastodongebruikers kunnen net zoals op andere ...
# 7                                                None
# 8                                       Join the team
# 9   All servers listed here have committed to the ...
# 10  Mastodon might look like a Twitter clone at fi...
# 11  Eind 2022 waren er maandelijks ruim 2,4 miljoe...
# 12      Mastodon is dus opensourcesoftware dat bes...
# 13                                               None
# 14                                               None
# 15  There is no such thing as a social network cal...
# 16                                               None
# 17  Het is nog onduidelijk of Twitter straks inder...
# 18              Click below to learn more in a video:
# 19                                               None
# 20        Beluister hier het gesprek in "De ochtend":
# 21                                               None
# 22  Mastodons disappeared along with many other No...
#
#                                           Paragraphs6  \
# 0                                                None
# 1   Mastodon is vrije en opensourcesoftware. Wij g...
# 2   Mastodon is free and open-source software. We ...
# 3                                                None
# 4   Since version 2.9.0, Mastodon has offered a si...
# 5           Waar de aanbieder wettelijk is gevestigd.
# 6   Openbare tijdlijnen kunnen ook op taal gefilte...
# 7                                                None
# 8                         What others write about us.
# 9                Where the provider is legally based.
# 10  When you first create your account, you choose...
# 11  Hoe gebruik je het, in vogelvlucht? Je maakt e...
# 12      Wees overigens niet bang dat je belangrijk...
# 13                                               None
# 14                                               None
# 15  Every Instance has its own independent server,...
# 16                                               None
# 17  Mastodon is op dit moment overigens nog vrij k...
# 18                                               None
# 19                                               None
# 20  Veel Twittergebruikers zouden daarom een overs...
# 21                                               None
# 22  In a letter dating to 1813, Edward Hyde, 3rd E...
#
#                                           Paragraphs7  ...  \
# 0                                                None  ...
# 1   We respecteren jouw handelsbekwaamheid. Jouw t...  ...
# 2   We respect your agency. Your feed is curated a...  ...
# 3                                                None  ...
# 4   Users join a specific Mastodon server, rather ...  ...
# 5   Sommige aanbieders zijn gespecialiseerd in het...  ...
# 6   Als gevolg van de open standaarden bestaan er ...  ...
# 7                                                None  ...
# 8   Free, open-source decentralized social media p...  ...
# 9   Some providers specialize in hosting accounts ...  ...
# 10  Mastodon users generally refer to individual c...  ...
# 11  Het streven van Mastodon is goed. Door de tran...  ...
# 12      Wil je dus beginnen met Mastodon? Dan kun ...  ...
# 13                                               None  ...
# 14                                               None  ...
# 15  From any Instance it is possible to interact w...  ...
# 16                                               None  ...
# 17  Het Duitse Mastodon moet echter nog wel aan de...  ...
# 18                                               None  ...
# 19                                               None  ...
# 20  Het is een project dat is opgezet door vrijwil...  ...
# 21                                               None  ...
# 22  Abeel reported in a later that he went to the ...  ...
#
#                                         Paragraphs121  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Or, if you just want to follow the account tha...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs122  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  This will cause a popup menu to appear from wh...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs123  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Once you enter your Mastodon Address and press...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs124 Paragraphs125  \
# 0                                                None          None
# 1                                                None          None
# 2                                                None          None
# 3                                                None          None
# 4                                                None          None
# 5                                                None          None
# 6                                                None          None
# 7                                                None          None
# 8                                                None          None
# 9                                                None          None
# 10                                               None          None
# 11                                               None          None
# 12                                               None          None
# 13                                               None          None
# 14                                               None          None
# 15  That’s it! Now you can open the PeerTube accou...          None
# 16                                               None          None
# 17                                               None          None
# 18                                               None          None
# 19                                               None          None
# 20                                               None          None
# 21                                               None          None
# 22                                               None          None
#
#                                         Paragraphs126  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Mastodon is by far the most widely used platfo...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs127  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  At the same time, however, its development tea...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs128  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Moreover, the implementation of content views ...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs129  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Finally, to make the current trend of reproduc...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                         Paragraphs130
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  We think that in a social context that is cult...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
# [23 rows x 133 columns]

# %% [markdown]
# Removing rows where it's mostly empty.
# I'm doing this because when you have a lot of data that doesn't bring much with only 10% filled of the max length of the dataset it is illogical to keep it.
# it also removes rows where it couldn't scrape anything from.

# %%
threshold: int =round(len(df.columns)*0.10)+2 # 2 is added so it doesn't include the columns `Link` and `Paragraphs`
print(threshold)
df= df.mask(df.eq('None')).dropna(axis=0, thresh=threshold)
df=df.reset_index()
df
# Out:
# 15
#    index                                               Link  \
# 0      1                     https://joinmastodon.org/nl-NL
# 1      2                          https://joinmastodon.org/
# 2      4  https://en.wikipedia.org/wiki/Mastodon_(social...
# 3      6  https://nl.wikipedia.org/wiki/Mastodon_(software)
# 4     10  https://techcrunch.com/2023/07/24/what-is-mast...
# 5     12  https://androidworld.nl/tips/mastodon-voor-beg...
# 6     15                             https://mastodon.help/
# 7     18               https://github.com/mastodon/mastodon
# 8     20  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 9     22             https://en.wikipedia.org/wiki/Mastodon
#
#                                           Paragraphs  \
# 0  [[Jouw tijdlijn zou vol moeten staan met wat v...
# 1  [[Your home feed should be filled with what ma...
# 2  [[\n], [[Mastodon],  is a , [free and open-sou...
# 3  [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 4  [[As Twitter users fret over the , [direction]...
# 5  [[\n                                    , [\n ...
# 6  [[Hello :-), [], After about two months since ...
# 7  [[We read every piece of feedback, and take yo...
# 8  [["Mastodon" wordt door sommigen naar voren ge...
# 9  [[\n], [A , [mastodon],  (, [<a class="extiw" ...
#
#                                          Paragraphs0  \
# 0  Jouw tijdlijn zou vol moeten staan met wat voo...
# 1  Your home feed should be filled with what matt...
# 2                                               None
# 3  Android: 2.3.0 (13 februari 2024)3 iOS: 1.5.2 ...
# 4  As Twitter users fret over the direction that ...
# 5                                                ...
# 6  Hello :-)After about two months since we repla...
# 7  We read every piece of feedback, and take your...
# 8  "Mastodon" wordt door sommigen naar voren gesc...
# 9                                               None
#
#                                          Paragraphs1  \
# 0  Je weet zelf het beste wat je op jouw tijdlijn...
# 1  You know best what you want to see on your hom...
# 2  Mastodon is a free and open-source software fo...
# 3  Mastodon is sinds 2016 opensourcesoftware om z...
# 4  Since October 27, when the SpaceX and Tesla CE...
# 5      Mastodon is ineens volop in het nieuws. Di...
# 6  Mastodon is a Free and Open Source microbloggi...
# 7              To see all available qualifiers, s...
# 8  Waarover gaat het? Techmiljardair Elon Musk he...
# 9  A mastodon (mastós 'breast' + odoús 'tooth') i...
#
#                                          Paragraphs2  \
# 0  Mastodon biedt je een unieke mogelijkheid om j...
# 1  Mastodon provides you with a unique possibilit...
# 2  Each user is a member of a specific Mastodon s...
# 3  Een Mastodon-site is te vergelijken met Twitte...
# 4  If you’re a Twitter purist who likes to use ba...
# 5      Mastodon is opensourcesoftware waarmee ied...
# 6  But Mastodon is not a Twitter clone: it is str...
# 7          Your self-hosted, globally interconnec...
# 8  Platformen met minimale moderatie worden heel ...
# 9  M. americanum, known as an "American mastodon"...
#
#                                          Paragraphs3  \
# 0  Mastodon legt de besluitvorming weer in jouw h...
# 1  Mastodon puts decision making back in your han...
# 2  Mastodon was created by Eugen Rochko and annou...
# 3  Het netwerk kreeg meer bekendheid na de overna...
# 4  Mastodon was founded in 2016 by German softwar...
# 5      Nee, Mastodon is in 2016 ontworpen door de...
# 6  This page, that was last updated at the end of...
# 7                                               None
# 8  Alleen is dat niet ideaal op het internet. "De...
# 9  Taxonomically, M. americanum was first recogni...
#
#                                          Paragraphs4  \
# 0  Mastodon ondersteunt audio-, video- en fotober...
# 1  Mastodon supports audio, video and picture pos...
# 2  The project is maintained by German non-profit...
# 3  Net zoals Twitter gebruikt de Mastodon web-app...
# 4  “Unlike the past 5 years that I’ve been runnin...
# 5      Nog een groot verschil met Twitter is het ...
# 6  The site also features a search engine for Mas...
# 7  Mastodon is a free, open-source social network...
# 8  Ook het wispelturige karakter van Musk speelt ...
# 9  As a member of the Mammutidae, it is defined b...
#
#                                          Paragraphs5  \
# 0  Directe wereldwijde communicatie is te belangr...
# 1  Instant global communication is too important ...
# 2  Mastodon servers run social networking softwar...
# 3  Mastodongebruikers kunnen net zoals op andere ...
# 4  Mastodon might look like a Twitter clone at fi...
# 5      Mastodon is dus opensourcesoftware dat bes...
# 6  There is no such thing as a social network cal...
# 7              Click below to learn more in a video:
# 8        Beluister hier het gesprek in "De ochtend":
# 9  Mastodons disappeared along with many other No...
#
#                                          Paragraphs6  ...  \
# 0  Mastodon is vrije en opensourcesoftware. Wij g...  ...
# 1  Mastodon is free and open-source software. We ...  ...
# 2  Since version 2.9.0, Mastodon has offered a si...  ...
# 3  Openbare tijdlijnen kunnen ook op taal gefilte...  ...
# 4  When you first create your account, you choose...  ...
# 5      Wees overigens niet bang dat je belangrijk...  ...
# 6  Every Instance has its own independent server,...  ...
# 7                                               None  ...
# 8  Veel Twittergebruikers zouden daarom een overs...  ...
# 9  In a letter dating to 1813, Edward Hyde, 3rd E...  ...
#
#                                        Paragraphs121  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  Or, if you just want to follow the account tha...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs122  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  This will cause a popup menu to appear from wh...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs123  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  Once you enter your Mastodon Address and press...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs124 Paragraphs125  \
# 0                                               None          None
# 1                                               None          None
# 2                                               None          None
# 3                                               None          None
# 4                                               None          None
# 5                                               None          None
# 6  That’s it! Now you can open the PeerTube accou...          None
# 7                                               None          None
# 8                                               None          None
# 9                                               None          None
#
#                                        Paragraphs126  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  Mastodon is by far the most widely used platfo...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs127  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  At the same time, however, its development tea...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs128  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  Moreover, the implementation of content views ...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs129  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  Finally, to make the current trend of reproduc...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                        Paragraphs130
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  We think that in a social context that is cult...
# 7                                               None
# 8                                               None
# 9                                               None
#
# [10 rows x 134 columns]

# %% [markdown]
# In the block below I delete the columns where the most amount of columns are filled.
# I have done this secondly after checking the rows of mostly empty rows because otherwise I will remove too many columns``

# %%
for i in range(max_para):
    column: str =("Paragraphs")+i.__str__()
    empty_string_count = (df[column].values == '').sum()
    empty_string_count = (df[column].values == None).sum() + empty_string_count

    if empty_string_count > df[column].count():
        #print(column)
        df.drop(column, axis=1, inplace=True)

# %%
df.drop("index",axis=1,inplace=True)
df
# Out:
#                                                 Link  \
# 0                     https://joinmastodon.org/nl-NL
# 1                          https://joinmastodon.org/
# 2  https://en.wikipedia.org/wiki/Mastodon_(social...
# 3  https://nl.wikipedia.org/wiki/Mastodon_(software)
# 4  https://techcrunch.com/2023/07/24/what-is-mast...
# 5  https://androidworld.nl/tips/mastodon-voor-beg...
# 6                             https://mastodon.help/
# 7               https://github.com/mastodon/mastodon
# 8  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 9             https://en.wikipedia.org/wiki/Mastodon
#
#                                           Paragraphs  \
# 0  [[Jouw tijdlijn zou vol moeten staan met wat v...
# 1  [[Your home feed should be filled with what ma...
# 2  [[\n], [[Mastodon],  is a , [free and open-sou...
# 3  [[[Android:],  2.3.0 , [(13 februari 2024)], [...
# 4  [[As Twitter users fret over the , [direction]...
# 5  [[\n                                    , [\n ...
# 6  [[Hello :-), [], After about two months since ...
# 7  [[We read every piece of feedback, and take yo...
# 8  [["Mastodon" wordt door sommigen naar voren ge...
# 9  [[\n], [A , [mastodon],  (, [<a class="extiw" ...
#
#                                          Paragraphs0  \
# 0  Jouw tijdlijn zou vol moeten staan met wat voo...
# 1  Your home feed should be filled with what matt...
# 2                                               None
# 3  Android: 2.3.0 (13 februari 2024)3 iOS: 1.5.2 ...
# 4  As Twitter users fret over the direction that ...
# 5                                                ...
# 6  Hello :-)After about two months since we repla...
# 7  We read every piece of feedback, and take your...
# 8  "Mastodon" wordt door sommigen naar voren gesc...
# 9                                               None
#
#                                          Paragraphs1  \
# 0  Je weet zelf het beste wat je op jouw tijdlijn...
# 1  You know best what you want to see on your hom...
# 2  Mastodon is a free and open-source software fo...
# 3  Mastodon is sinds 2016 opensourcesoftware om z...
# 4  Since October 27, when the SpaceX and Tesla CE...
# 5      Mastodon is ineens volop in het nieuws. Di...
# 6  Mastodon is a Free and Open Source microbloggi...
# 7              To see all available qualifiers, s...
# 8  Waarover gaat het? Techmiljardair Elon Musk he...
# 9  A mastodon (mastós 'breast' + odoús 'tooth') i...
#
#                                          Paragraphs2  \
# 0  Mastodon biedt je een unieke mogelijkheid om j...
# 1  Mastodon provides you with a unique possibilit...
# 2  Each user is a member of a specific Mastodon s...
# 3  Een Mastodon-site is te vergelijken met Twitte...
# 4  If you’re a Twitter purist who likes to use ba...
# 5      Mastodon is opensourcesoftware waarmee ied...
# 6  But Mastodon is not a Twitter clone: it is str...
# 7          Your self-hosted, globally interconnec...
# 8  Platformen met minimale moderatie worden heel ...
# 9  M. americanum, known as an "American mastodon"...
#
#                                          Paragraphs3  \
# 0  Mastodon legt de besluitvorming weer in jouw h...
# 1  Mastodon puts decision making back in your han...
# 2  Mastodon was created by Eugen Rochko and annou...
# 3  Het netwerk kreeg meer bekendheid na de overna...
# 4  Mastodon was founded in 2016 by German softwar...
# 5      Nee, Mastodon is in 2016 ontworpen door de...
# 6  This page, that was last updated at the end of...
# 7                                               None
# 8  Alleen is dat niet ideaal op het internet. "De...
# 9  Taxonomically, M. americanum was first recogni...
#
#                                          Paragraphs4  \
# 0  Mastodon ondersteunt audio-, video- en fotober...
# 1  Mastodon supports audio, video and picture pos...
# 2  The project is maintained by German non-profit...
# 3  Net zoals Twitter gebruikt de Mastodon web-app...
# 4  “Unlike the past 5 years that I’ve been runnin...
# 5      Nog een groot verschil met Twitter is het ...
# 6  The site also features a search engine for Mas...
# 7  Mastodon is a free, open-source social network...
# 8  Ook het wispelturige karakter van Musk speelt ...
# 9  As a member of the Mammutidae, it is defined b...
#
#                                          Paragraphs5  \
# 0  Directe wereldwijde communicatie is te belangr...
# 1  Instant global communication is too important ...
# 2  Mastodon servers run social networking softwar...
# 3  Mastodongebruikers kunnen net zoals op andere ...
# 4  Mastodon might look like a Twitter clone at fi...
# 5      Mastodon is dus opensourcesoftware dat bes...
# 6  There is no such thing as a social network cal...
# 7              Click below to learn more in a video:
# 8        Beluister hier het gesprek in "De ochtend":
# 9  Mastodons disappeared along with many other No...
#
#                                          Paragraphs6  \
# 0  Mastodon is vrije en opensourcesoftware. Wij g...
# 1  Mastodon is free and open-source software. We ...
# 2  Since version 2.9.0, Mastodon has offered a si...
# 3  Openbare tijdlijnen kunnen ook op taal gefilte...
# 4  When you first create your account, you choose...
# 5      Wees overigens niet bang dat je belangrijk...
# 6  Every Instance has its own independent server,...
# 7                                               None
# 8  Veel Twittergebruikers zouden daarom een overs...
# 9  In a letter dating to 1813, Edward Hyde, 3rd E...
#
#                                          Paragraphs7  ...  \
# 0  We respecteren jouw handelsbekwaamheid. Jouw t...  ...
# 1  We respect your agency. Your feed is curated a...  ...
# 2  Users join a specific Mastodon server, rather ...  ...
# 3  Als gevolg van de open standaarden bestaan er ...  ...
# 4  Mastodon users generally refer to individual c...  ...
# 5      Wil je dus beginnen met Mastodon? Dan kun ...  ...
# 6  From any Instance it is possible to interact w...  ...
# 7                                               None  ...
# 8  Het is een project dat is opgezet door vrijwil...  ...
# 9  Abeel reported in a later that he went to the ...  ...
#
#                                         Paragraphs30  \
# 0                                               None
# 1                                               None
# 2  Following the Mastodon suspension and ban on M...
# 3                                               None
# 4  You can add up to four images to a post, up to...
# 5      Veel mensen die net 'op Mastodon' zitten, ...
# 6  You can read more about this topic in our Crit...
# 7                                               None
# 8                                               None
# 9  In 1930, Matthew erected a second species for ...
#
#                                         Paragraphs31  \
# 0                                               None
# 1                                               None
# 2  Rochko claimed that at least five venture capi...
# 3                                               None
# 4  Similar to how Twitter now allows users to lim...
# 5      Ga je Mastodon of een van de andere Fedive...
# 6  Considering the large number of tools Mastodon...
# 7                                               None
# 8                                               None
# 9  In 1933, Childs Frick named the species Mastod...
#
#                                         Paragraphs32  \
# 0                                               None
# 1                                               None
# 2  By the start of January 2023, Mastodon had 1.8...
# 3                                               None
# 4  Yep! But this functionality isn’t built into M...
# 5                 Met dank aan Gerhard voor de hulp!
# 6  In contrast, reality is quite different, and i...
# 7                                               None
# 8                                               None
# 9  In 1963, J. Arnold Shotwell and Donald E. Russ...
#
#                                         Paragraphs33  \
# 0                                               None
# 1                                               None
# 2  In 2017, Pixiv launched a Mastodon-based socia...
# 3                                               None
# 4  No. There’s no universal verification system l...
# 5  Every Mastodon explanation is like "It's very ...
# 6  While it is technically possible for those who...
# 7                                               None
# 8                                               None
# 9  The genus Pliomastodon was synonymized with Ma...
#
#                                         Paragraphs34  \
# 0                                               None
# 1                                               None
# 2  In April 2019, computer manufacturer Purism re...
# 3                                               None
# 4  Some servers are having fun with the idea of v...
# 5                             @Ciaraioch@mastodon.ie
# 6  Since its inception, Mastodon has been adopted...
# 7                                               None
# 8                                               None
# 9  In 2019, Alton C. Dooley Jr. et. al. establish...
#
#                                         Paragraphs36  \
# 0                                               None
# 1                                               None
# 2  In October 2019, the Fourth Estate Public Bene...
# 3                                               None
# 4  Image Credits: @stux@mstdn.social (opens in a ...
# 5                                                ...
# 6  Each Mastodon Instance is independent, has its...
# 7                                               None
# 8                                               None
# 9  Several mammutid species outside of North Amer...
#
#                                         Paragraphs38  \
# 0                                               None
# 1                                               None
# 2  In October 2021, former US President Donald Tr...
# 3                                               None
# 4  Mastodon is experiencing a massive influx of n...
# 5                          donderdag, 14 maart 20...
# 6  However, due to the federated nature of the pl...
# 7                                               None
# 8                                               None
# 9  Although the separation of the Mammutida and E...
#
#                                         Paragraphs39  \
# 0                                               None
# 1                                               None
# 2  While Mastodon's decentralized structure is on...
# 3                                               None
# 4  Yes, this is possible by way of third-party to...
# 5                                                ...
# 6  On smartphones, Mastodon can be used from any ...
# 7                                               None
# 8                                               None
# 9  In the early Neogene phase of evolution, Eozyg...
#
#                                         Paragraphs40  \
# 0                                               None
# 1                                               None
# 2  Since many Mastodon instances are run by volun...
# 3                                               None
# 4  Yes, this is also possible with third-party to...
# 5                                                ...
# 6  On Android, the best known Apps are Mastodon (...
# 7                                               None
# 8                                               None
# 9  Mammut as currently defined sensu lato (in a l...
#
#                                         Paragraphs41
# 0                                               None
# 1                                               None
# 2  Volunteer-run instances may not have resources...
# 3                                               None
# 4  Nope — not unless Bluesky chooses to adopt the...
# 5                          donderdag, 14 maart 20...
# 6  On iOS you have a similar amount of choice, wi...
# 7                                               None
# 8                                               None
# 9  The oldest evidence of mammutids in North Amer...
#
# [10 rows x 41 columns]

# %% [markdown]
# ## Send information back

# %%
df_cleaned = df
df_cleaned.drop("Paragraphs",axis=1,inplace=True)
df_cleaned
# Out:
#                                                 Link  \
# 0                     https://joinmastodon.org/nl-NL
# 1                          https://joinmastodon.org/
# 2  https://en.wikipedia.org/wiki/Mastodon_(social...
# 3  https://nl.wikipedia.org/wiki/Mastodon_(software)
# 4  https://techcrunch.com/2023/07/24/what-is-mast...
# 5  https://androidworld.nl/tips/mastodon-voor-beg...
# 6                             https://mastodon.help/
# 7               https://github.com/mastodon/mastodon
# 8  https://www.vrt.be/vrtnws/nl/2022/11/01/mastod...
# 9             https://en.wikipedia.org/wiki/Mastodon
#
#                                          Paragraphs0  \
# 0  Jouw tijdlijn zou vol moeten staan met wat voo...
# 1  Your home feed should be filled with what matt...
# 2                                               None
# 3  Android: 2.3.0 (13 februari 2024)3 iOS: 1.5.2 ...
# 4  As Twitter users fret over the direction that ...
# 5                                                ...
# 6  Hello :-)After about two months since we repla...
# 7  We read every piece of feedback, and take your...
# 8  "Mastodon" wordt door sommigen naar voren gesc...
# 9                                               None
#
#                                          Paragraphs1  \
# 0  Je weet zelf het beste wat je op jouw tijdlijn...
# 1  You know best what you want to see on your hom...
# 2  Mastodon is a free and open-source software fo...
# 3  Mastodon is sinds 2016 opensourcesoftware om z...
# 4  Since October 27, when the SpaceX and Tesla CE...
# 5      Mastodon is ineens volop in het nieuws. Di...
# 6  Mastodon is a Free and Open Source microbloggi...
# 7              To see all available qualifiers, s...
# 8  Waarover gaat het? Techmiljardair Elon Musk he...
# 9  A mastodon (mastós 'breast' + odoús 'tooth') i...
#
#                                          Paragraphs2  \
# 0  Mastodon biedt je een unieke mogelijkheid om j...
# 1  Mastodon provides you with a unique possibilit...
# 2  Each user is a member of a specific Mastodon s...
# 3  Een Mastodon-site is te vergelijken met Twitte...
# 4  If you’re a Twitter purist who likes to use ba...
# 5      Mastodon is opensourcesoftware waarmee ied...
# 6  But Mastodon is not a Twitter clone: it is str...
# 7          Your self-hosted, globally interconnec...
# 8  Platformen met minimale moderatie worden heel ...
# 9  M. americanum, known as an "American mastodon"...
#
#                                          Paragraphs3  \
# 0  Mastodon legt de besluitvorming weer in jouw h...
# 1  Mastodon puts decision making back in your han...
# 2  Mastodon was created by Eugen Rochko and annou...
# 3  Het netwerk kreeg meer bekendheid na de overna...
# 4  Mastodon was founded in 2016 by German softwar...
# 5      Nee, Mastodon is in 2016 ontworpen door de...
# 6  This page, that was last updated at the end of...
# 7                                               None
# 8  Alleen is dat niet ideaal op het internet. "De...
# 9  Taxonomically, M. americanum was first recogni...
#
#                                          Paragraphs4  \
# 0  Mastodon ondersteunt audio-, video- en fotober...
# 1  Mastodon supports audio, video and picture pos...
# 2  The project is maintained by German non-profit...
# 3  Net zoals Twitter gebruikt de Mastodon web-app...
# 4  “Unlike the past 5 years that I’ve been runnin...
# 5      Nog een groot verschil met Twitter is het ...
# 6  The site also features a search engine for Mas...
# 7  Mastodon is a free, open-source social network...
# 8  Ook het wispelturige karakter van Musk speelt ...
# 9  As a member of the Mammutidae, it is defined b...
#
#                                          Paragraphs5  \
# 0  Directe wereldwijde communicatie is te belangr...
# 1  Instant global communication is too important ...
# 2  Mastodon servers run social networking softwar...
# 3  Mastodongebruikers kunnen net zoals op andere ...
# 4  Mastodon might look like a Twitter clone at fi...
# 5      Mastodon is dus opensourcesoftware dat bes...
# 6  There is no such thing as a social network cal...
# 7              Click below to learn more in a video:
# 8        Beluister hier het gesprek in "De ochtend":
# 9  Mastodons disappeared along with many other No...
#
#                                          Paragraphs6  \
# 0  Mastodon is vrije en opensourcesoftware. Wij g...
# 1  Mastodon is free and open-source software. We ...
# 2  Since version 2.9.0, Mastodon has offered a si...
# 3  Openbare tijdlijnen kunnen ook op taal gefilte...
# 4  When you first create your account, you choose...
# 5      Wees overigens niet bang dat je belangrijk...
# 6  Every Instance has its own independent server,...
# 7                                               None
# 8  Veel Twittergebruikers zouden daarom een overs...
# 9  In a letter dating to 1813, Edward Hyde, 3rd E...
#
#                                          Paragraphs7  \
# 0  We respecteren jouw handelsbekwaamheid. Jouw t...
# 1  We respect your agency. Your feed is curated a...
# 2  Users join a specific Mastodon server, rather ...
# 3  Als gevolg van de open standaarden bestaan er ...
# 4  Mastodon users generally refer to individual c...
# 5      Wil je dus beginnen met Mastodon? Dan kun ...
# 6  From any Instance it is possible to interact w...
# 7                                               None
# 8  Het is een project dat is opgezet door vrijwil...
# 9  Abeel reported in a later that he went to the ...
#
#                                          Paragraphs8  ...  \
# 0  Mastodon is gebouwd op open webprotocollen en ...  ...
# 1  Built on open web protocols, Mastodon can spea...  ...
# 2  Mastodon includes a number of specific privacy...  ...
# 3  Het maakt net zoals bij e-mail in principe nie...  ...
# 4  Choosing which server to register your account...  ...
# 5      Elke Instance is volledig onafhankelijk en...  ...
# 6  Those who administer an Instance may limit or ...  ...
# 7  It doesn't have to be Mastodon; whatever imple...  ...
# 8  "Het lijkt op het eerste zicht wel wat op Twit...  ...
# 9  In 1739, a French military expedition under th...  ...
#
#                                         Paragraphs30  \
# 0                                               None
# 1                                               None
# 2  Following the Mastodon suspension and ban on M...
# 3                                               None
# 4  You can add up to four images to a post, up to...
# 5      Veel mensen die net 'op Mastodon' zitten, ...
# 6  You can read more about this topic in our Crit...
# 7                                               None
# 8                                               None
# 9  In 1930, Matthew erected a second species for ...
#
#                                         Paragraphs31  \
# 0                                               None
# 1                                               None
# 2  Rochko claimed that at least five venture capi...
# 3                                               None
# 4  Similar to how Twitter now allows users to lim...
# 5      Ga je Mastodon of een van de andere Fedive...
# 6  Considering the large number of tools Mastodon...
# 7                                               None
# 8                                               None
# 9  In 1933, Childs Frick named the species Mastod...
#
#                                         Paragraphs32  \
# 0                                               None
# 1                                               None
# 2  By the start of January 2023, Mastodon had 1.8...
# 3                                               None
# 4  Yep! But this functionality isn’t built into M...
# 5                 Met dank aan Gerhard voor de hulp!
# 6  In contrast, reality is quite different, and i...
# 7                                               None
# 8                                               None
# 9  In 1963, J. Arnold Shotwell and Donald E. Russ...
#
#                                         Paragraphs33  \
# 0                                               None
# 1                                               None
# 2  In 2017, Pixiv launched a Mastodon-based socia...
# 3                                               None
# 4  No. There’s no universal verification system l...
# 5  Every Mastodon explanation is like "It's very ...
# 6  While it is technically possible for those who...
# 7                                               None
# 8                                               None
# 9  The genus Pliomastodon was synonymized with Ma...
#
#                                         Paragraphs34  \
# 0                                               None
# 1                                               None
# 2  In April 2019, computer manufacturer Purism re...
# 3                                               None
# 4  Some servers are having fun with the idea of v...
# 5                             @Ciaraioch@mastodon.ie
# 6  Since its inception, Mastodon has been adopted...
# 7                                               None
# 8                                               None
# 9  In 2019, Alton C. Dooley Jr. et. al. establish...
#
#                                         Paragraphs36  \
# 0                                               None
# 1                                               None
# 2  In October 2019, the Fourth Estate Public Bene...
# 3                                               None
# 4  Image Credits: @stux@mstdn.social (opens in a ...
# 5                                                ...
# 6  Each Mastodon Instance is independent, has its...
# 7                                               None
# 8                                               None
# 9  Several mammutid species outside of North Amer...
#
#                                         Paragraphs38  \
# 0                                               None
# 1                                               None
# 2  In October 2021, former US President Donald Tr...
# 3                                               None
# 4  Mastodon is experiencing a massive influx of n...
# 5                          donderdag, 14 maart 20...
# 6  However, due to the federated nature of the pl...
# 7                                               None
# 8                                               None
# 9  Although the separation of the Mammutida and E...
#
#                                         Paragraphs39  \
# 0                                               None
# 1                                               None
# 2  While Mastodon's decentralized structure is on...
# 3                                               None
# 4  Yes, this is possible by way of third-party to...
# 5                                                ...
# 6  On smartphones, Mastodon can be used from any ...
# 7                                               None
# 8                                               None
# 9  In the early Neogene phase of evolution, Eozyg...
#
#                                         Paragraphs40  \
# 0                                               None
# 1                                               None
# 2  Since many Mastodon instances are run by volun...
# 3                                               None
# 4  Yes, this is also possible with third-party to...
# 5                                                ...
# 6  On Android, the best known Apps are Mastodon (...
# 7                                               None
# 8                                               None
# 9  Mammut as currently defined sensu lato (in a l...
#
#                                         Paragraphs41
# 0                                               None
# 1                                               None
# 2  Volunteer-run instances may not have resources...
# 3                                               None
# 4  Nope — not unless Bluesky chooses to adopt the...
# 5                          donderdag, 14 maart 20...
# 6  On iOS you have a similar amount of choice, wi...
# 7                                               None
# 8                                               None
# 9  The oldest evidence of mammutids in North Amer...
#
# [10 rows x 40 columns]

# %%
df_cleaned.to_json("./ResultOfSearchAndScrapeBot.json")

# %% [markdown]
# ## What's next?
# Now comes the part where it needs to be send too something.
#
# ## Improvements
#
# - Connect to the platform and get the search part.
# - Send data back
